# %%
 pip install livelossplot
# Out:
# Collecting livelossplot
#   Downloading livelossplot-0.5.5-py3-none-any.whl (22 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from livelossplot) (3.7.1)
# Requirement already satisfied: bokeh in /usr/local/lib/python3.10/dist-packages (from livelossplot) (3.3.1)
# Requirement already satisfied: Jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from bokeh->livelossplot) (3.1.2)
# Requirement already satisfied: contourpy>=1 in /usr/local/lib/python3.10/dist-packages (from bokeh->livelossplot) (1.2.0)
# Requirement already satisfied: numpy>=1.16 in /usr/local/lib/python3.10/dist-packages (from bokeh->livelossplot) (1.23.5)
# Requirement already satisfied: packaging>=16.8 in /usr/local/lib/python3.10/dist-packages (from bokeh->livelossplot) (23.2)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.10/dist-packages (from bokeh->livelossplot) (1.5.3)
# Requirement already satisfied: pillow>=7.1.0 in /usr/local/lib/python3.10/dist-packages (from bokeh->livelossplot) (9.4.0)
# Requirement already satisfied: PyYAML>=3.10 in /usr/local/lib/python3.10/dist-packages (from bokeh->livelossplot) (6.0.1)
# Requirement already satisfied: tornado>=5.1 in /usr/local/lib/python3.10/dist-packages (from bokeh->livelossplot) (6.3.2)
# Requirement already satisfied: xyzservices>=2021.09.1 in /usr/local/lib/python3.10/dist-packages (from bokeh->livelossplot) (2023.10.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->livelossplot) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->livelossplot) (4.44.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->livelossplot) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->livelossplot) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->livelossplot) (2.8.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=2.9->bokeh->livelossplot) (2.1.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->bokeh->livelossplot) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->livelossplot) (1.16.0)
# Installing collected packages: livelossplot
# Successfully installed livelossplot-0.5.5

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import os
from glob import glob
from PIL import Image
import numpy as np
import pandas as pd
import cv2
import random
import albumentations as A
import keras
import matplotlib.cm as cm
import plotly.express as px
import plotly.figure_factory as ff
import matplotlib.pyplot as plt
import seaborn as sns
from livelossplot.inputs.keras import PlotLossesCallback
from keras.callbacks import ModelCheckpoint, EarlyStopping

from sklearn.model_selection import train_test_split
from keras.preprocessing import image
from tensorflow.keras import layers, models
import tensorflow as tf
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report, recall_score, accuracy_score, precision_score, f1_score

# %% [markdown]
# With the csv file Example & on dataset 2

# %%
import numpy as np
import os
import matplotlib.pyplot as plt

import cv2
from tqdm import tqdm
import io
import seaborn as sns

from sklearn.utils import shuffle # Shuffle arrays or sparse matrices in a consistent way
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

from tensorflow.keras.applications import DenseNet121
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, TensorBoard,ModelCheckpoint

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score


import ipywidgets as widgets
from PIL import Image
from IPython.display import display, clear_output

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Activation, Dropout,Dense, Flatten, BatchNormalization, Conv2D, MaxPooling2D, Lambda, Input, AveragePooling2D
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model, Sequential
from keras.callbacks import ReduceLROnPlateau, LearningRateScheduler
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from imutils import paths
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import random
import shutil
import cv2
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Define Labels

# %%
labels = ['COVID', 'Normal', 'Lung_Opacity', 'Viral Pneumonia']

# %%
X_train = [] #Training Dataset
Y_train = [] #Training Labels

image_size=70

for i in labels:
    folderPath = os.path.join('/content/drive/MyDrive/COVID-19_Radiography_Dataset',  i)
    for j in tqdm(os.listdir(folderPath)):
        image = cv2.imread(os.path.join(folderPath, j))
        image = cv2.resize(image, (image_size, image_size))
        X_train.append(image)
        Y_train.append(i)



# converted into array

Xtrain = np.array(X_train)
Ytrain = np.array(Y_train)
# Out:
# 100%|██████████| 3646/3646 [01:09<00:00, 52.29it/s]
# 100%|██████████| 10192/10192 [03:19<00:00, 50.99it/s]
# 100%|██████████| 6012/6012 [01:53<00:00, 53.07it/s]
# 100%|██████████| 1348/1348 [00:22<00:00, 61.21it/s]

# %%
Xtrain.shape
# Out:
# (21198, 70, 70, 3)

# %%
Ytrain.shape
# Out:
# (21198,)

# %%
Xtrain,Ytrain = shuffle(Xtrain, Ytrain, random_state=42)

# %%
xtrain, xtest, ytrain, ytest = train_test_split(Xtrain, Ytrain, test_size = 0.2, random_state = 42)
xtrain, xval, ytrain, yval = train_test_split(xtrain, ytrain, test_size = 0.10101, random_state = 42)

# %% [markdown]
# ## Train test split which is divided train dataset and validation dataset

# %%
xtrain,xtest, ytrain,ytest = train_test_split(Xtrain, Ytrain,test_size=0.281112, random_state=42)

# %%
xtrain.shape
# Out:
# (15245, 70, 70, 3)

# %%
ytrain.shape
# Out:
# (15262,)

# %%
xtest.shape
# Out:
# (4240, 70, 70, 3)

# %%
ytest.shape
# Out:
# (4240,)

# %% [markdown]
# ## Converting labels into One hot encoder

# %%
ytrain_new = []
ytest_new = []

for i in ytrain:
    ytrain_new.append(labels.index(i))#Converting String Label to integer i.e

ytrain = to_categorical(ytrain_new) #Converts a class vector (integers) to binary class matrix

for i in ytest:
    ytest_new.append(labels.index(i))

ytest = to_categorical(ytest_new)

# %%
ytrain.shape
# Out:
# (15238, 4)

# %%
ytest.shape
# Out:
# (5960, 4)

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# Data Reading

import os
from glob import glob
from PIL import Image

# Data Processing

import numpy as np
import pandas as pd
import cv2
import random
import albumentations as A

# Data Analysis

import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns

# Data Modeling & Model Evaluation

from sklearn.model_selection import train_test_split
from keras.preprocessing import image
from tensorflow.keras import layers, models
import tensorflow as tf
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report, recall_score, accuracy_score, precision_score, f1_score

# Grad-CAM

import keras
import matplotlib.cm as cm

# %% [markdown]
# # DENSENET MODEL

# %%
image_size = 224

# %%
model_d=DenseNet121(weights='imagenet',include_top=False, input_shape=(image_size, image_size, 3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 [==============================] - 2s 0us/step

# %%
# Output of model

model = model_d.output
model = tf.keras.layers.AveragePooling2D(pool_size=(4, 4))(model)
model = tf.keras.layers.Flatten(name="flatten")(model)
model = tf.keras.layers.Dense(128, activation="relu")(model)
model = tf.keras.layers.Dropout(0.6)(model)
model = tf.keras.layers.Dense(4, activation='softmax')(model)
model = tf.keras.models.Model(inputs=model_d.input, outputs=model)

# %%
METRICS = [
      tf.keras.metrics.BinaryAccuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),
      tf.keras.metrics.AUC(name='auc')
]

# %%
model.compile( optimizer='adam',
    loss='categorical_crossentropy',
    metrics=METRICS)

# %%
history=model.load_weights('/content/drive/MyDrive/DENSE_M224.h5')

# %%
#es = tf.keras.callbacks.EarlyStopping(monitor = 'val_loss', mode = 'min', verbose = 1, patience = 4)

#tf.random.set_seed(42)
history = model.fit(xtrain,ytrain,
                        epochs = 50,
                        validation_data = (xtest,ytest))
# Out:
# Epoch 1/50
# 530/530 [==============================] - 145s 140ms/step - loss: 0.5097 - accuracy: 0.9139 - precision: 0.8578 - recall: 0.7859 - auc: 0.9553 - val_loss: 0.6778 - val_accuracy: 0.8907 - val_precision: 0.7955 - val_recall: 0.7578 - val_auc: 0.9288
# Epoch 2/50
# 530/530 [==============================] - 69s 130ms/step - loss: 0.3152 - accuracy: 0.9474 - precision: 0.9061 - recall: 0.8811 - auc: 0.9810 - val_loss: 0.5815 - val_accuracy: 0.9109 - val_precision: 0.8287 - val_recall: 0.8113 - val_auc: 0.9571
# Epoch 3/50
# 530/530 [==============================] - 69s 129ms/step - loss: 0.2593 - accuracy: 0.9570 - precision: 0.9214 - recall: 0.9052 - auc: 0.9863 - val_loss: 0.3541 - val_accuracy: 0.9366 - val_precision: 0.8789 - val_recall: 0.8658 - val_auc: 0.9772
# Epoch 4/50
# 530/530 [==============================] - 68s 129ms/step - loss: 0.2362 - accuracy: 0.9627 - precision: 0.9309 - recall: 0.9192 - auc: 0.9881 - val_loss: 0.8145 - val_accuracy: 0.8857 - val_precision: 0.7791 - val_recall: 0.7578 - val_auc: 0.9240
# Epoch 5/50
# 530/530 [==============================] - 69s 129ms/step - loss: 0.2128 - accuracy: 0.9651 - precision: 0.9352 - recall: 0.9246 - auc: 0.9903 - val_loss: 0.3831 - val_accuracy: 0.9391 - val_precision: 0.8850 - val_recall: 0.8693 - val_auc: 0.9747
# Epoch 6/50
# 530/530 [==============================] - 68s 129ms/step - loss: 0.2029 - accuracy: 0.9666 - precision: 0.9371 - recall: 0.9286 - auc: 0.9909 - val_loss: 0.4044 - val_accuracy: 0.9296 - val_precision: 0.8700 - val_recall: 0.8446 - val_auc: 0.9716
# Epoch 7/50
# 530/530 [==============================] - 68s 128ms/step - loss: 0.1861 - accuracy: 0.9688 - precision: 0.9416 - recall: 0.9333 - auc: 0.9923 - val_loss: 0.2926 - val_accuracy: 0.9545 - val_precision: 0.9135 - val_recall: 0.9038 - val_auc: 0.9832
# Epoch 8/50
# 530/530 [==============================] - 68s 128ms/step - loss: 0.1791 - accuracy: 0.9699 - precision: 0.9437 - recall: 0.9354 - auc: 0.9928 - val_loss: 0.5119 - val_accuracy: 0.9282 - val_precision: 0.8607 - val_recall: 0.8507 - val_auc: 0.9672
# Epoch 9/50
# 530/530 [==============================] - 68s 128ms/step - loss: 0.1616 - accuracy: 0.9734 - precision: 0.9496 - recall: 0.9439 - auc: 0.9938 - val_loss: 0.2023 - val_accuracy: 0.9649 - val_precision: 0.9342 - val_recall: 0.9248 - val_auc: 0.9914
# Epoch 10/50
# 530/530 [==============================] - 68s 128ms/step - loss: 0.1496 - accuracy: 0.9744 - precision: 0.9512 - recall: 0.9462 - auc: 0.9947 - val_loss: 0.4546 - val_accuracy: 0.9350 - val_precision: 0.8718 - val_recall: 0.8677 - val_auc: 0.9688
# Epoch 11/50
# 530/530 [==============================] - 68s 128ms/step - loss: 0.1432 - accuracy: 0.9750 - precision: 0.9525 - recall: 0.9473 - auc: 0.9950 - val_loss: 0.2820 - val_accuracy: 0.9590 - val_precision: 0.9197 - val_recall: 0.9158 - val_auc: 0.9850
# Epoch 12/50
# 530/530 [==============================] - 68s 128ms/step - loss: 0.1262 - accuracy: 0.9775 - precision: 0.9572 - recall: 0.9528 - auc: 0.9960 - val_loss: 1.5916 - val_accuracy: 0.8402 - val_precision: 0.6822 - val_recall: 0.6750 - val_auc: 0.8733
# Epoch 13/50
# 530/530 [==============================] - 68s 128ms/step - loss: 0.1213 - accuracy: 0.9786 - precision: 0.9586 - recall: 0.9555 - auc: 0.9962 - val_loss: 0.2403 - val_accuracy: 0.9650 - val_precision: 0.9312 - val_recall: 0.9285 - val_auc: 0.9881
# Epoch 14/50
# 530/530 [==============================] - 68s 128ms/step - loss: 0.1110 - accuracy: 0.9809 - precision: 0.9632 - recall: 0.9601 - auc: 0.9969 - val_loss: 0.2298 - val_accuracy: 0.9619 - val_precision: 0.9266 - val_recall: 0.9205 - val_auc: 0.9881
# Epoch 15/50
# 530/530 [==============================] - 68s 128ms/step - loss: 0.1057 - accuracy: 0.9812 - precision: 0.9639 - recall: 0.9607 - auc: 0.9971 - val_loss: 0.4482 - val_accuracy: 0.9466 - val_precision: 0.8958 - val_recall: 0.8901 - val_auc: 0.9717
# Epoch 16/50
# 530/530 [==============================] - 68s 128ms/step - loss: 0.1015 - accuracy: 0.9831 - precision: 0.9674 - recall: 0.9651 - auc: 0.9972 - val_loss: 0.4069 - val_accuracy: 0.9479 - val_precision: 0.8973 - val_recall: 0.8939 - val_auc: 0.9783
# Epoch 17/50
# 530/530 [==============================] - 68s 128ms/step - loss: 0.0857 - accuracy: 0.9851 - precision: 0.9708 - recall: 0.9693 - auc: 0.9977 - val_loss: 0.5517 - val_accuracy: 0.9217 - val_precision: 0.8463 - val_recall: 0.8392 - val_auc: 0.9635
# Epoch 18/50
# 530/530 [==============================] - 68s 128ms/step - loss: 0.0864 - accuracy: 0.9850 - precision: 0.9710 - recall: 0.9690 - auc: 0.9978 - val_loss: 0.2850 - val_accuracy: 0.9659 - val_precision: 0.9322 - val_recall: 0.9311 - val_auc: 0.9848
# Epoch 19/50
# 530/530 [==============================] - 68s 128ms/step - loss: 0.0755 - accuracy: 0.9861 - precision: 0.9729 - recall: 0.9716 - auc: 0.9983 - val_loss: 0.3764 - val_accuracy: 0.9498 - val_precision: 0.9014 - val_recall: 0.8974 - val_auc: 0.9779
# Epoch 20/50
# 530/530 [==============================] - 68s 128ms/step - loss: 0.0782 - accuracy: 0.9867 - precision: 0.9744 - recall: 0.9722 - auc: 0.9980 - val_loss: 0.2489 - val_accuracy: 0.9663 - val_precision: 0.9336 - val_recall: 0.9314 - val_auc: 0.9881
# Epoch 21/50
# 530/530 [==============================] - 68s 128ms/step - loss: 0.0658 - accuracy: 0.9887 - precision: 0.9779 - recall: 0.9768 - auc: 0.9985 - val_loss: 0.3378 - val_accuracy: 0.9557 - val_precision: 0.9135 - val_recall: 0.9090 - val_auc: 0.9819
# Epoch 22/50
# 530/530 [==============================] - 68s 128ms/step - loss: 0.0557 - accuracy: 0.9908 - precision: 0.9819 - recall: 0.9814 - auc: 0.9987 - val_loss: 0.2933 - val_accuracy: 0.9640 - val_precision: 0.9295 - val_recall: 0.9264 - val_auc: 0.9847
# Epoch 23/50
# 530/530 [==============================] - 68s 128ms/step - loss: 0.0546 - accuracy: 0.9909 - precision: 0.9823 - recall: 0.9812 - auc: 0.9987 - val_loss: 0.2542 - val_accuracy: 0.9647 - val_precision: 0.9303 - val_recall: 0.9283 - val_auc: 0.9871
# Epoch 24/50
# 530/530 [==============================] - 68s 128ms/step - loss: 0.0593 - accuracy: 0.9895 - precision: 0.9797 - recall: 0.9782 - auc: 0.9988 - val_loss: 0.4215 - val_accuracy: 0.9619 - val_precision: 0.9248 - val_recall: 0.9226 - val_auc: 0.9778
# Epoch 25/50
# 530/530 [==============================] - 68s 128ms/step - loss: 0.0404 - accuracy: 0.9933 - precision: 0.9871 - recall: 0.9862 - auc: 0.9992 - val_loss: 0.3447 - val_accuracy: 0.9652 - val_precision: 0.9308 - val_recall: 0.9297 - val_auc: 0.9820
# Epoch 26/50
# 530/530 [==============================] - 68s 128ms/step - loss: 0.0499 - accuracy: 0.9911 - precision: 0.9825 - recall: 0.9818 - auc: 0.9991 - val_loss: 0.2840 - val_accuracy: 0.9674 - val_precision: 0.9351 - val_recall: 0.9344 - val_auc: 0.9868
# Epoch 27/50
# 530/530 [==============================] - 67s 127ms/step - loss: 0.0386 - accuracy: 0.9935 - precision: 0.9873 - recall: 0.9867 - auc: 0.9992 - val_loss: 0.8533 - val_accuracy: 0.9228 - val_precision: 0.8463 - val_recall: 0.8443 - val_auc: 0.9467
# Epoch 28/50
# 530/530 [==============================] - 68s 128ms/step - loss: 0.0414 - accuracy: 0.9929 - precision: 0.9862 - recall: 0.9854 - auc: 0.9993 - val_loss: 0.2924 - val_accuracy: 0.9636 - val_precision: 0.9283 - val_recall: 0.9257 - val_auc: 0.9836
# Epoch 29/50
# 530/530 [==============================] - 68s 127ms/step - loss: 0.0341 - accuracy: 0.9944 - precision: 0.9891 - recall: 0.9885 - auc: 0.9992 - val_loss: 0.3711 - val_accuracy: 0.9606 - val_precision: 0.9228 - val_recall: 0.9191 - val_auc: 0.9806
# Epoch 30/50
# 530/530 [==============================] - 67s 127ms/step - loss: 0.0274 - accuracy: 0.9953 - precision: 0.9909 - recall: 0.9904 - auc: 0.9997 - val_loss: 0.4403 - val_accuracy: 0.9567 - val_precision: 0.9146 - val_recall: 0.9118 - val_auc: 0.9750
# Epoch 31/50
# 530/530 [==============================] - 68s 127ms/step - loss: 0.0557 - accuracy: 0.9910 - precision: 0.9828 - recall: 0.9814 - auc: 0.9987 - val_loss: 0.3133 - val_accuracy: 0.9645 - val_precision: 0.9296 - val_recall: 0.9283 - val_auc: 0.9816
# Epoch 32/50
# 530/530 [==============================] - 67s 127ms/step - loss: 0.0334 - accuracy: 0.9944 - precision: 0.9891 - recall: 0.9885 - auc: 0.9994 - val_loss: 0.3674 - val_accuracy: 0.9625 - val_precision: 0.9256 - val_recall: 0.9243 - val_auc: 0.9787
# Epoch 33/50
# 530/530 [==============================] - 68s 128ms/step - loss: 0.0311 - accuracy: 0.9951 - precision: 0.9902 - recall: 0.9900 - auc: 0.9994 - val_loss: 0.2739 - val_accuracy: 0.9722 - val_precision: 0.9445 - val_recall: 0.9441 - val_auc: 0.9869
# Epoch 34/50
# 530/530 [==============================] - 69s 129ms/step - loss: 0.0265 - accuracy: 0.9954 - precision: 0.9910 - recall: 0.9907 - auc: 0.9996 - val_loss: 0.3901 - val_accuracy: 0.9674 - val_precision: 0.9351 - val_recall: 0.9344 - val_auc: 0.9803
# Epoch 35/50
# 530/530 [==============================] - 68s 129ms/step - loss: 0.0265 - accuracy: 0.9956 - precision: 0.9914 - recall: 0.9911 - auc: 0.9996 - val_loss: 0.5636 - val_accuracy: 0.9491 - val_precision: 0.8985 - val_recall: 0.8976 - val_auc: 0.9685
# Epoch 36/50
# 530/530 [==============================] - 68s 129ms/step - loss: 0.0343 - accuracy: 0.9942 - precision: 0.9888 - recall: 0.9880 - auc: 0.9994 - val_loss: 0.3813 - val_accuracy: 0.9689 - val_precision: 0.9382 - val_recall: 0.9375 - val_auc: 0.9817
# Epoch 37/50
# 530/530 [==============================] - 68s 129ms/step - loss: 0.0282 - accuracy: 0.9951 - precision: 0.9904 - recall: 0.9900 - auc: 0.9995 - val_loss: 0.4981 - val_accuracy: 0.9631 - val_precision: 0.9270 - val_recall: 0.9255 - val_auc: 0.9780
# Epoch 38/50
# 530/530 [==============================] - 68s 129ms/step - loss: 0.0245 - accuracy: 0.9959 - precision: 0.9919 - recall: 0.9916 - auc: 0.9996 - val_loss: 0.3818 - val_accuracy: 0.9686 - val_precision: 0.9379 - val_recall: 0.9363 - val_auc: 0.9816
# Epoch 39/50
# 530/530 [==============================] - 68s 129ms/step - loss: 0.0298 - accuracy: 0.9953 - precision: 0.9908 - recall: 0.9906 - auc: 0.9994 - val_loss: 0.3317 - val_accuracy: 0.9688 - val_precision: 0.9377 - val_recall: 0.9373 - val_auc: 0.9834
# Epoch 40/50
# 530/530 [==============================] - 68s 129ms/step - loss: 0.0267 - accuracy: 0.9963 - precision: 0.9929 - recall: 0.9925 - auc: 0.9994 - val_loss: 0.3564 - val_accuracy: 0.9692 - val_precision: 0.9388 - val_recall: 0.9377 - val_auc: 0.9830
# Epoch 41/50
# 530/530 [==============================] - 68s 129ms/step - loss: 0.0303 - accuracy: 0.9953 - precision: 0.9907 - recall: 0.9904 - auc: 0.9995 - val_loss: 0.3378 - val_accuracy: 0.9692 - val_precision: 0.9388 - val_recall: 0.9377 - val_auc: 0.9832
# Epoch 42/50
# 530/530 [==============================] - 69s 129ms/step - loss: 0.0217 - accuracy: 0.9966 - precision: 0.9933 - recall: 0.9929 - auc: 0.9996 - val_loss: 0.3645 - val_accuracy: 0.9683 - val_precision: 0.9372 - val_recall: 0.9358 - val_auc: 0.9803
# Epoch 43/50
# 530/530 [==============================] - 68s 129ms/step - loss: 0.0260 - accuracy: 0.9960 - precision: 0.9921 - recall: 0.9917 - auc: 0.9994 - val_loss: 0.3246 - val_accuracy: 0.9643 - val_precision: 0.9296 - val_recall: 0.9274 - val_auc: 0.9816
# Epoch 44/50
# 530/530 [==============================] - 68s 129ms/step - loss: 0.0293 - accuracy: 0.9957 - precision: 0.9915 - recall: 0.9912 - auc: 0.9993 - val_loss: 0.3214 - val_accuracy: 0.9701 - val_precision: 0.9407 - val_recall: 0.9396 - val_auc: 0.9845
# Epoch 45/50
# 530/530 [==============================] - 68s 129ms/step - loss: 0.0152 - accuracy: 0.9975 - precision: 0.9950 - recall: 0.9950 - auc: 0.9998 - val_loss: 0.3797 - val_accuracy: 0.9711 - val_precision: 0.9426 - val_recall: 0.9417 - val_auc: 0.9807
# Epoch 46/50
# 530/530 [==============================] - 68s 128ms/step - loss: 0.0206 - accuracy: 0.9969 - precision: 0.9940 - recall: 0.9938 - auc: 0.9996 - val_loss: 0.4990 - val_accuracy: 0.9532 - val_precision: 0.9071 - val_recall: 0.9054 - val_auc: 0.9727
# Epoch 47/50
# 530/530 [==============================] - 68s 129ms/step - loss: 0.0263 - accuracy: 0.9958 - precision: 0.9920 - recall: 0.9914 - auc: 0.9995 - val_loss: 0.4888 - val_accuracy: 0.9631 - val_precision: 0.9266 - val_recall: 0.9257 - val_auc: 0.9759
# Epoch 48/50
# 530/530 [==============================] - 69s 129ms/step - loss: 0.0223 - accuracy: 0.9966 - precision: 0.9933 - recall: 0.9930 - auc: 0.9995 - val_loss: 0.3189 - val_accuracy: 0.9716 - val_precision: 0.9434 - val_recall: 0.9432 - val_auc: 0.9846
# Epoch 49/50
# 530/530 [==============================] - 68s 129ms/step - loss: 0.0198 - accuracy: 0.9971 - precision: 0.9942 - recall: 0.9941 - auc: 0.9996 - val_loss: 0.4840 - val_accuracy: 0.9505 - val_precision: 0.9027 - val_recall: 0.8991 - val_auc: 0.9714
# Epoch 50/50
# 530/530 [==============================] - 68s 129ms/step - loss: 0.0223 - accuracy: 0.9967 - precision: 0.9937 - recall: 0.9933 - auc: 0.9996 - val_loss: 0.3792 - val_accuracy: 0.9692 - val_precision: 0.9386 - val_recall: 0.9380 - val_auc: 0.9825

# %%
import pandas as pd

# Assuming 'history1' is the History object returned from model.fit()
metrics = pd.DataFrame(history.history)

# Save the training history to a CSV file
metrics.to_csv('/content/sample_data/DENSE_M224.csv', index=False)

# Save the model itself
model.save('/content/sample_data/DENSE_M224.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
pred = model.predict(xtest)
pred = np.argmax(pred, axis=1)
actual_label = np.argmax(ytest, axis=1)
print(classification_report(actual_label, pred , target_names = labels))
# Out:
# 133/133 [==============================] - 23s 93ms/step
#                  precision    recall  f1-score   support
#
#           COVID       0.99      0.92      0.95       733
#          Normal       0.93      0.96      0.95      2057
#    Lung_Opacity       0.91      0.89      0.90      1152
# Viral Pneumonia       0.97      0.98      0.97       298
#
#        accuracy                           0.94      4240
#       macro avg       0.95      0.94      0.94      4240
#    weighted avg       0.94      0.94      0.94      4240

# %%
accuracy_score(actual_label, pred)
# Out:
# 0.9384433962264151

# %%
Cm=confusion_matrix(actual_label,pred)
ax=plt.axes()
sns.heatmap(Cm, cmap='Blues' ,annot=True,fmt='d',
           annot_kws={'size':10},
           xticklabels=labels,
           yticklabels=labels,
           ax=ax
           )

plt.title("Confusion Matrix for Covid-19 Classification using DenseNet121")
plt.savefig('densenet_confusion.png', dpi=300) # Save plot as PNG
plt.show()

# %% [markdown]
# ## Loss and Accuracy Measurement graph

# %%
# Plot the training and validation accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('DenseNet Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Training', 'Validation'])
plt.savefig('densenet_accuracy.png', dpi=300) # Save plot as PNG
plt.show()

# Plot the training and validation loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('DenseNet Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Training', 'Validation'])
plt.savefig('densenet_loss.png', dpi=300) # Save plot as PNG
plt.show()

# %%
# Plot the training and validation auc
plt.plot(history.history['auc'])
plt.plot(history.history['val_auc'])
plt.title('DenseNet Model AUC')
plt.xlabel('Epoch')
plt.ylabel('AUC')
plt.legend(['Training', 'Validation'])
plt.savefig('densenet_auc.png', dpi=300) # Save plot as PNG
plt.show()

# Plot the training and validation precision
plt.plot(history.history['precision'])
plt.plot(history.history['val_precision'])
plt.title('DenseNet Model Precision')
plt.xlabel('Epoch')
plt.ylabel('Precision')
plt.legend(['Training', 'Validation'])
plt.savefig('densenet_precision.png', dpi=300) # Save plot as PNG
plt.show()

# %% [markdown]
# ## CNN MODEL

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras import layers
image_size = 224

# %%
model1 = Sequential()

model1.add(Conv2D(128, (3, 3), activation='relu', input_shape=(70, 70, 3)))
model1.add(MaxPooling2D((2, 2)))
model1.add(Dropout(0.3))

model1.add(Conv2D(64, (3, 3), activation='relu'))
model1.add(MaxPooling2D((2, 2)))
model1.add(Dropout(0.5))

model1.add(Conv2D(32, (3, 3), activation='relu'))
model1.add(Flatten())
model1.add(Dense(units=16, activation='relu'))
model1.add(Dropout(0.2))

model1.add(Dense(units=4))

# %%
cnn_model = models.Sequential()
cnn_model.add(layers.Conv2D(filters = 128, kernel_size = (3, 3), activation = 'relu', input_shape = (224, 224, 3)))
cnn_model.add(layers.MaxPooling2D((2, 2)))
cnn_model.add(layers.Dropout(0.3))

cnn_model.add(layers.Conv2D(filters = 64, kernel_size = (3, 3), activation = 'relu'))
cnn_model.add(layers.MaxPooling2D((2, 2)))
cnn_model.add(layers.Dropout(0.5))

cnn_model.add(layers.Conv2D(filters = 64, kernel_size = (3, 3), activation = 'relu'))
cnn_model.add(layers.Flatten())
cnn_model.add(layers.Dense(units = 16, activation = 'relu'))
cnn_model.add(layers.Dropout(0.2))

cnn_model.add(layers.Dense(units = 4))

cnn_model.compile(optimizer = 'adam',
           loss = 'categorical_crossentropy',
           metrics=METRICS)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-3d267657f0ea> in <cell line: 1>()
# ----> 1 cnn_model = models.Sequential()
#       2 cnn_model.add(layers.Conv2D(filters = 128, kernel_size = (3, 3), activation = 'relu', input_shape = (224, 224, 3)))
#       3 cnn_model.add(layers.MaxPooling2D((2, 2)))
#       4 cnn_model.add(layers.Dropout(0.3))
#       5
#
# NameError: name 'models' is not defined

# %%
model2 = Sequential()
model2.add(Conv2D(32,kernel_size=(3,3),activation='relu',input_shape=(224,224,3)))
model2.add(Conv2D(64,(3,3),activation='relu'))
model2.add(MaxPooling2D(pool_size=(2,2)))
model2.add(Dropout(0.25))
model2.add(Conv2D(128,(3,3),activation='relu'))
model2.add(MaxPooling2D(pool_size=(2,2)))
model2.add(Dropout(0.25))

model2.add(Flatten())
model2.add(Dense(64,activation='relu'))
model2.add(Dropout(0.5))
model2.add(Dense(2,activation='softmax'))
#model2.compile(loss=keras.losses.binary_crossentropy,optimizer='adam',metrics=['accuracy',keras.metrics.Precision(),keras.metrics.Recall()])

# %%
#Create the model
cnn=Sequential()
#initially 64 convolution nodes
cnn.add(Conv2D(64,(3,3),padding="same",activation='relu',input_shape=(image_size, image_size, 3)))
#add a Max Pooling layer
cnn.add(MaxPooling2D())
#another 32 convolution nodes
cnn.add(Conv2D(32,(3,3),padding="same",activation='relu'))
#Add a max pooling
cnn.add(MaxPooling2D())
#Add 32 convolutions
cnn.add(Conv2D(32,(2,2),padding="same",activation='relu'))
#Add a max pooling
cnn.add(MaxPooling2D())
#Flatten before adding fully connected layer
cnn.add(Flatten())
#Add a hidden layer with 100 nodes
cnn.add(Dense(100,activation='relu'))
#Add another hidden layer with 50 nodes
cnn.add(Dense(50,activation='relu'))
#Add final output layer with 4 output nodes using softmax
cnn.add(Dense(4,activation='softmax'))

# %%
cnn.compile( optimizer='adam',
    loss='categorical_crossentropy',
    metrics=METRICS)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-109-b8f1df894749> in <cell line: 1>()
# ----> 1 cnn.compile( optimizer='adam',
#       2     loss='categorical_crossentropy',
#       3     metrics=METRICS)
#
# NameError: name 'cnn' is not defined

# %%
model1.compile( optimizer='adam',
    loss='categorical_crossentropy',
    metrics=METRICS)

# %%
model1.load_weights('/content/drive/MyDrive/tl_model_v1.weights.best.hdf5')

# %%
model16.compile( optimizer='adam',
    loss='categorical_crossentropy',
    metrics=METRICS)

# %%
import numpy as np
import matplotlib.pyplot as plt
import keras
from keras.layers import *
from keras.models import *
from keras.preprocessing import image

# %%
import numpy as np
import matplotlib.pyplot as plt
import keras
from keras.layers import *
from keras.models import *
from keras.preprocessing import image

# %%
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
# Out:
# Physical devices cannot be modified after being initialized

# %%
history2=model1.fit(xtrain,ytrain,epochs=50,validation_data=(xtest,ytest))
# Out:
# Epoch 1/50
# 477/477 [==============================] - 10s 16ms/step - loss: 6.1843 - accuracy: 0.5108 - precision: 0.2671 - recall: 0.5484 - auc: 0.5235 - val_loss: 4.3793 - val_accuracy: 0.3642 - val_precision: 0.2428 - val_recall: 0.7283 - val_auc: 0.4855
# Epoch 2/50
# 477/477 [==============================] - 7s 15ms/step - loss: 5.1701 - accuracy: 0.4354 - precision: 0.2374 - recall: 0.5687 - auc: 0.4752 - val_loss: 4.3793 - val_accuracy: 0.3642 - val_precision: 0.2428 - val_recall: 0.7283 - val_auc: 0.4855
# Epoch 3/50
# 477/477 [==============================] - 7s 15ms/step - loss: 5.5256 - accuracy: 0.3810 - precision: 0.2403 - recall: 0.6828 - auc: 0.4810 - val_loss: 4.3793 - val_accuracy: 0.3642 - val_precision: 0.2428 - val_recall: 0.7283 - val_auc: 0.4855
# Epoch 4/50
# 477/477 [==============================] - 7s 15ms/step - loss: 5.5602 - accuracy: 0.3725 - precision: 0.2408 - recall: 0.7011 - auc: 0.4819 - val_loss: 4.3793 - val_accuracy: 0.3642 - val_precision: 0.2428 - val_recall: 0.7283 - val_auc: 0.4855
# Epoch 5/50
# 477/477 [==============================] - 7s 15ms/step - loss: 5.6226 - accuracy: 0.3713 - precision: 0.2404 - recall: 0.7017 - auc: 0.4813 - val_loss: 4.3793 - val_accuracy: 0.3642 - val_precision: 0.2428 - val_recall: 0.7283 - val_auc: 0.4855
# Epoch 6/50
# 477/477 [==============================] - 7s 15ms/step - loss: 5.6057 - accuracy: 0.3725 - precision: 0.2409 - recall: 0.7018 - auc: 0.4821 - val_loss: 4.3793 - val_accuracy: 0.3642 - val_precision: 0.2428 - val_recall: 0.7283 - val_auc: 0.4855
# Epoch 7/50
# 477/477 [==============================] - 7s 15ms/step - loss: 5.6575 - accuracy: 0.3716 - precision: 0.2404 - recall: 0.7010 - auc: 0.4812 - val_loss: 4.3793 - val_accuracy: 0.3642 - val_precision: 0.2428 - val_recall: 0.7283 - val_auc: 0.4855
# Epoch 8/50
# 477/477 [==============================] - 7s 15ms/step - loss: 5.5655 - accuracy: 0.3727 - precision: 0.2411 - recall: 0.7027 - auc: 0.4827 - val_loss: 4.3793 - val_accuracy: 0.3642 - val_precision: 0.2428 - val_recall: 0.7283 - val_auc: 0.4855
# Epoch 9/50
# 477/477 [==============================] - 7s 15ms/step - loss: 5.5993 - accuracy: 0.3731 - precision: 0.2411 - recall: 0.7019 - auc: 0.4825 - val_loss: 4.3793 - val_accuracy: 0.3642 - val_precision: 0.2428 - val_recall: 0.7283 - val_auc: 0.4855
# Epoch 10/50
# 477/477 [==============================] - 7s 15ms/step - loss: 5.6025 - accuracy: 0.3730 - precision: 0.2409 - recall: 0.7012 - auc: 0.4822 - val_loss: 4.3793 - val_accuracy: 0.3642 - val_precision: 0.2428 - val_recall: 0.7283 - val_auc: 0.4855
# Epoch 11/50
# 477/477 [==============================] - 7s 15ms/step - loss: 5.6839 - accuracy: 0.3734 - precision: 0.2410 - recall: 0.7006 - auc: 0.4823 - val_loss: 4.3793 - val_accuracy: 0.3642 - val_precision: 0.2428 - val_recall: 0.7283 - val_auc: 0.4855
# Epoch 12/50
# 477/477 [==============================] - 7s 15ms/step - loss: 5.6797 - accuracy: 0.3733 - precision: 0.2410 - recall: 0.7011 - auc: 0.4826 - val_loss: 4.3793 - val_accuracy: 0.3642 - val_precision: 0.2428 - val_recall: 0.7283 - val_auc: 0.4855
# Epoch 13/50
# 477/477 [==============================] - 7s 15ms/step - loss: 5.6849 - accuracy: 0.3719 - precision: 0.2405 - recall: 0.7008 - auc: 0.4814 - val_loss: 4.3793 - val_accuracy: 0.3642 - val_precision: 0.2428 - val_recall: 0.7283 - val_auc: 0.4855
# Epoch 14/50
# 477/477 [==============================] - 7s 15ms/step - loss: 5.5475 - accuracy: 0.3724 - precision: 0.2408 - recall: 0.7013 - auc: 0.4819 - val_loss: 4.3793 - val_accuracy: 0.3642 - val_precision: 0.2428 - val_recall: 0.7283 - val_auc: 0.4855
# Epoch 15/50
# 477/477 [==============================] - 7s 15ms/step - loss: 5.6109 - accuracy: 0.3725 - precision: 0.2405 - recall: 0.7000 - auc: 0.4814 - val_loss: 4.3793 - val_accuracy: 0.3642 - val_precision: 0.2428 - val_recall: 0.7283 - val_auc: 0.4855
# Epoch 16/50
# 477/477 [==============================] - 7s 15ms/step - loss: 5.6501 - accuracy: 0.3719 - precision: 0.2408 - recall: 0.7027 - auc: 0.4821 - val_loss: 4.3793 - val_accuracy: 0.3642 - val_precision: 0.2428 - val_recall: 0.7283 - val_auc: 0.4855
# Epoch 17/50
# 477/477 [==============================] - 7s 15ms/step - loss: 5.6183 - accuracy: 0.3710 - precision: 0.2404 - recall: 0.7020 - auc: 0.4813 - val_loss: 4.3793 - val_accuracy: 0.3642 - val_precision: 0.2428 - val_recall: 0.7283 - val_auc: 0.4855
# Epoch 18/50
# 477/477 [==============================] - 7s 15ms/step - loss: 5.5655 - accuracy: 0.3716 - precision: 0.2404 - recall: 0.7010 - auc: 0.4813 - val_loss: 4.3793 - val_accuracy: 0.3642 - val_precision: 0.2428 - val_recall: 0.7283 - val_auc: 0.4855
# Epoch 19/50
# 477/477 [==============================] - 7s 15ms/step - loss: 5.6152 - accuracy: 0.3722 - precision: 0.2405 - recall: 0.7003 - auc: 0.4815 - val_loss: 4.3793 - val_accuracy: 0.3642 - val_precision: 0.2428 - val_recall: 0.7283 - val_auc: 0.4855
# Epoch 20/50
# 477/477 [==============================] - 7s 15ms/step - loss: 5.6109 - accuracy: 0.3720 - precision: 0.2407 - recall: 0.7016 - auc: 0.4816 - val_loss: 4.3793 - val_accuracy: 0.3642 - val_precision: 0.2428 - val_recall: 0.7283 - val_auc: 0.4855
# Epoch 21/50
# 477/477 [==============================] - 7s 15ms/step - loss: 5.6025 - accuracy: 0.3723 - precision: 0.2409 - recall: 0.7025 - auc: 0.4821 - val_loss: 4.3793 - val_accuracy: 0.3642 - val_precision: 0.2428 - val_recall: 0.7283 - val_auc: 0.4855
# Epoch 22/50
# 477/477 [==============================] - 7s 15ms/step - loss: 5.6384 - accuracy: 0.3741 - precision: 0.2414 - recall: 0.7017 - auc: 0.4832 - val_loss: 4.3793 - val_accuracy: 0.3642 - val_precision: 0.2428 - val_recall: 0.7283 - val_auc: 0.4855
# Epoch 23/50
# 477/477 [==============================] - 7s 15ms/step - loss: 5.5909 - accuracy: 0.3721 - precision: 0.2405 - recall: 0.7006 - auc: 0.4814 - val_loss: 4.3793 - val_accuracy: 0.3642 - val_precision: 0.2428 - val_recall: 0.7283 - val_auc: 0.4855
# Epoch 24/50
# 477/477 [==============================] - 7s 15ms/step - loss: 5.5813 - accuracy: 0.3732 - precision: 0.2412 - recall: 0.7023 - auc: 0.4827 - val_loss: 4.3793 - val_accuracy: 0.3642 - val_precision: 0.2428 - val_recall: 0.7283 - val_auc: 0.4855
# Epoch 25/50
# 477/477 [==============================] - 7s 15ms/step - loss: 5.5433 - accuracy: 0.3720 - precision: 0.2407 - recall: 0.7018 - auc: 0.4817 - val_loss: 4.3793 - val_accuracy: 0.3642 - val_precision: 0.2428 - val_recall: 0.7283 - val_auc: 0.4855
# Epoch 26/50
# 477/477 [==============================] - 7s 15ms/step - loss: 5.6405 - accuracy: 0.3740 - precision: 0.2415 - recall: 0.7028 - auc: 0.4835 - val_loss: 4.3793 - val_accuracy: 0.3642 - val_precision: 0.2428 - val_recall: 0.7283 - val_auc: 0.4855
# Epoch 27/50
# 477/477 [==============================] - 7s 15ms/step - loss: 5.6701 - accuracy: 0.3728 - precision: 0.2408 - recall: 0.7008 - auc: 0.4819 - val_loss: 4.3793 - val_accuracy: 0.3642 - val_precision: 0.2428 - val_recall: 0.7283 - val_auc: 0.4855
# Epoch 28/50
# 477/477 [==============================] - 7s 15ms/step - loss: 5.7124 - accuracy: 0.3734 - precision: 0.2411 - recall: 0.7015 - auc: 0.4827 - val_loss: 4.3793 - val_accuracy: 0.3642 - val_precision: 0.2428 - val_recall: 0.7283 - val_auc: 0.4855
# Epoch 29/50
# 477/477 [==============================] - 7s 15ms/step - loss: 5.6067 - accuracy: 0.3713 - precision: 0.2404 - recall: 0.7012 - auc: 0.4811 - val_loss: 4.3793 - val_accuracy: 0.3642 - val_precision: 0.2428 - val_recall: 0.7283 - val_auc: 0.4855
# Epoch 30/50
# 477/477 [==============================] - 7s 15ms/step - loss: 5.5856 - accuracy: 0.3727 - precision: 0.2409 - recall: 0.7015 - auc: 0.4822 - val_loss: 4.3793 - val_accuracy: 0.3642 - val_precision: 0.2428 - val_recall: 0.7283 - val_auc: 0.4855
# Epoch 31/50
# 477/477 [==============================] - 7s 15ms/step - loss: 5.5877 - accuracy: 0.3726 - precision: 0.2408 - recall: 0.7014 - auc: 0.4820 - val_loss: 4.3793 - val_accuracy: 0.3642 - val_precision: 0.2428 - val_recall: 0.7283 - val_auc: 0.4855
# Epoch 32/50
# 477/477 [==============================] - 7s 15ms/step - loss: 5.6247 - accuracy: 0.3729 - precision: 0.2409 - recall: 0.7010 - auc: 0.4823 - val_loss: 4.3793 - val_accuracy: 0.3642 - val_precision: 0.2428 - val_recall: 0.7283 - val_auc: 0.4855
# Epoch 33/50
# 477/477 [==============================] - 7s 15ms/step - loss: 5.5686 - accuracy: 0.3736 - precision: 0.2412 - recall: 0.7015 - auc: 0.4828 - val_loss: 4.3793 - val_accuracy: 0.3642 - val_precision: 0.2428 - val_recall: 0.7283 - val_auc: 0.4855
# Epoch 34/50
# 477/477 [==============================] - 7s 15ms/step - loss: 5.6384 - accuracy: 0.3733 - precision: 0.2409 - recall: 0.7004 - auc: 0.4821 - val_loss: 4.3793 - val_accuracy: 0.3642 - val_precision: 0.2428 - val_recall: 0.7283 - val_auc: 0.4855
# Epoch 35/50
# 477/477 [==============================] - 7s 15ms/step - loss: 5.7008 - accuracy: 0.3741 - precision: 0.2412 - recall: 0.7008 - auc: 0.4830 - val_loss: 4.3793 - val_accuracy: 0.3642 - val_precision: 0.2428 - val_recall: 0.7283 - val_auc: 0.4855
# Epoch 36/50
# 477/477 [==============================] - 7s 15ms/step - loss: 5.5877 - accuracy: 0.3727 - precision: 0.2407 - recall: 0.7002 - auc: 0.4818 - val_loss: 4.3793 - val_accuracy: 0.3642 - val_precision: 0.2428 - val_recall: 0.7283 - val_auc: 0.4855
# Epoch 37/50
# 477/477 [==============================] - 7s 15ms/step - loss: 5.6131 - accuracy: 0.3715 - precision: 0.2404 - recall: 0.7009 - auc: 0.4810 - val_loss: 4.3793 - val_accuracy: 0.3642 - val_precision: 0.2428 - val_recall: 0.7283 - val_auc: 0.4855
# Epoch 38/50
# 477/477 [==============================] - 7s 15ms/step - loss: 5.5676 - accuracy: 0.3726 - precision: 0.2407 - recall: 0.7007 - auc: 0.4818 - val_loss: 4.3793 - val_accuracy: 0.3642 - val_precision: 0.2428 - val_recall: 0.7283 - val_auc: 0.4855
# Epoch 39/50
# 477/477 [==============================] - 7s 15ms/step - loss: 5.6046 - accuracy: 0.3714 - precision: 0.2406 - recall: 0.7021 - auc: 0.4815 - val_loss: 4.3793 - val_accuracy: 0.3642 - val_precision: 0.2428 - val_recall: 0.7283 - val_auc: 0.4855
# Epoch 40/50
# 477/477 [==============================] - 7s 15ms/step - loss: 5.6310 - accuracy: 0.3721 - precision: 0.2405 - recall: 0.7005 - auc: 0.4814 - val_loss: 4.3793 - val_accuracy: 0.3642 - val_precision: 0.2428 - val_recall: 0.7283 - val_auc: 0.4855
# Epoch 41/50
# 477/477 [==============================] - 7s 15ms/step - loss: 5.5887 - accuracy: 0.3732 - precision: 0.2409 - recall: 0.7009 - auc: 0.4823 - val_loss: 4.3793 - val_accuracy: 0.3642 - val_precision: 0.2428 - val_recall: 0.7283 - val_auc: 0.4855
# Epoch 42/50
# 477/477 [==============================] - 7s 15ms/step - loss: 5.5771 - accuracy: 0.3730 - precision: 0.2409 - recall: 0.7008 - auc: 0.4821 - val_loss: 4.3793 - val_accuracy: 0.3642 - val_precision: 0.2428 - val_recall: 0.7283 - val_auc: 0.4855
# Epoch 43/50
# 477/477 [==============================] - 7s 15ms/step - loss: 5.6152 - accuracy: 0.3723 - precision: 0.2407 - recall: 0.7014 - auc: 0.4819 - val_loss: 4.3793 - val_accuracy: 0.3642 - val_precision: 0.2428 - val_recall: 0.7283 - val_auc: 0.4855
# Epoch 44/50
# 477/477 [==============================] - 7s 15ms/step - loss: 5.5602 - accuracy: 0.3723 - precision: 0.2410 - recall: 0.7030 - auc: 0.4826 - val_loss: 4.3793 - val_accuracy: 0.3642 - val_precision: 0.2428 - val_recall: 0.7283 - val_auc: 0.4855
# Epoch 45/50
# 477/477 [==============================] - 7s 15ms/step - loss: 5.6226 - accuracy: 0.3715 - precision: 0.2404 - recall: 0.7012 - auc: 0.4813 - val_loss: 4.3793 - val_accuracy: 0.3642 - val_precision: 0.2428 - val_recall: 0.7283 - val_auc: 0.4855
# Epoch 46/50
# 477/477 [==============================] - 7s 15ms/step - loss: 5.5264 - accuracy: 0.3717 - precision: 0.2403 - recall: 0.6998 - auc: 0.4808 - val_loss: 4.3793 - val_accuracy: 0.3642 - val_precision: 0.2428 - val_recall: 0.7283 - val_auc: 0.4855
# Epoch 47/50
# 477/477 [==============================] - 7s 15ms/step - loss: 5.7029 - accuracy: 0.3736 - precision: 0.2411 - recall: 0.7011 - auc: 0.4827 - val_loss: 4.3793 - val_accuracy: 0.3642 - val_precision: 0.2428 - val_recall: 0.7283 - val_auc: 0.4855
# Epoch 48/50
# 477/477 [==============================] - 7s 15ms/step - loss: 5.6543 - accuracy: 0.3732 - precision: 0.2411 - recall: 0.7020 - auc: 0.4826 - val_loss: 4.3793 - val_accuracy: 0.3642 - val_precision: 0.2428 - val_recall: 0.7283 - val_auc: 0.4855
# Epoch 49/50
# 477/477 [==============================] - 7s 15ms/step - loss: 5.6078 - accuracy: 0.3725 - precision: 0.2407 - recall: 0.7010 - auc: 0.4818 - val_loss: 4.3793 - val_accuracy: 0.3642 - val_precision: 0.2428 - val_recall: 0.7283 - val_auc: 0.4855
# Epoch 50/50
# 477/477 [==============================] - 7s 15ms/step - loss: 5.6353 - accuracy: 0.3720 - precision: 0.2408 - recall: 0.7021 - auc: 0.4819 - val_loss: 4.3793 - val_accuracy: 0.3642 - val_precision: 0.2428 - val_recall: 0.7283 - val_auc: 0.4855

# %%
import pandas as pd

# Assuming 'history1' is the History object returned from model.fit()
metrics = pd.DataFrame(history2.history)

# Save the training history to a CSV file
metrics.to_csv('/content/sample_data/CNN2.csv', index=False)

# Save the model itself
cnn_model.save('/content/sample_data/CNN_B224.h5')

# %%
pred1 = model1.predict(xtest)
pred1 = np.argmax(pred1, axis=1)
actual_label1 = np.argmax(ytest, axis=1)
print(classification_report(actual_label1, pred1 , target_names = labels))
# Out:
# 133/133 [==============================] - 0s 3ms/step
#                  precision    recall  f1-score   support
#
#           COVID       0.00      0.00      0.00       733
#          Normal       0.00      0.00      0.00      2057
#    Lung_Opacity       0.00      0.00      0.00      1152
# Viral Pneumonia       0.07      1.00      0.13       298
#
#        accuracy                           0.07      4240
#       macro avg       0.02      0.25      0.03      4240
#    weighted avg       0.00      0.07      0.01      4240

# %%
pred1 = cnn.predict(xtest)
pred1 = np.argmax(pred1, axis=1)
actual_label1 = np.argmax(ytest, axis=1)
print(classification_report(actual_label1, pred1 , target_names = labels_final))
# Out:
# 87/87 [==============================] - 0s 5ms/step
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-4997f5922ea9> in <cell line: 4>()
#       2 pred1 = np.argmax(pred1, axis=1)
#       3 actual_label1 = np.argmax(ytest, axis=1)
# ----> 4 print(classification_report(actual_label1, pred1 , target_names = labels_final))
#
# NameError: name 'labels_final' is not defined

# %%
accuracy_score(actual_label1, pred1)
# Out:
# 0.9562861271676301

# %%
Cm1=confusion_matrix(actual_label1,pred1)
ax1=plt.axes()
sns.heatmap(Cm1, cmap='Blues' ,annot=True,fmt='d',
           annot_kws={'size':10},
           xticklabels=labels,
           yticklabels=labels,
           ax=ax1
           )

plt.title("Confusion Matrix for Covid-19 detection using CNN Model")
plt.savefig('cnn_confusion.png', dpi=300) # Save plot as PNG
plt.show()

# %% [markdown]
# ## Loss and Accuracy Measurement Graph - CNN Model

# %%
# Plot the training and validation accuracy
plt.plot(history2.history['accuracy'])
plt.plot(history2.history['val_accuracy'])
plt.title('CNN Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Training', 'Validation'])
plt.savefig('cnn_accuracy.png', dpi=300) # Save plot as PNG
plt.show()

# Plot the training and validation loss
plt.plot(history2.history['loss'])
plt.plot(history2.history['val_loss'])
plt.title('CNN Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Training', 'Validation'])
plt.savefig('cnn_loss.png', dpi=300) # Save plot as PNG
plt.show()

# %%
# Plot the training and validation auc
plt.plot(history2.history['auc'])
plt.plot(history2.history['val_auc'])
plt.title('CNN Model AUC')
plt.xlabel('Epoch')
plt.ylabel('AUC')
plt.legend(['Training', 'Validation'])
plt.savefig('cnn_auc.png', dpi=300) # Save plot as PNG
plt.show()

# Plot the training and validation precision
plt.plot(history2.history['precision'])
plt.plot(history2.history['val_precision'])
plt.title('CNN Model Precision')
plt.xlabel('Epoch')
plt.ylabel('Precision')
plt.legend(['Training', 'Validation'])
plt.savefig('cnn_precision.png', dpi=300) # Save plot as PNG
plt.show()

# %% [markdown]
# ## Efficient NetB7 Model

# %%
from tensorflow.keras.applications.inception_v3 import InceptionV3

# %%
image_size = 150

# %%
inceptionv3 = InceptionV3(include_top=False,weights='imagenet',input_shape=(image_size, image_size, 3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 3s 0us/step

# %%
original_image_path="/content/sample_data/COVID-13.png"

# %%
from PIL import Image
import os

# Open the original image

img = Image.open(original_image_path)

# Resize the image to 150x150 pixels
resized_img = img.resize((150, 150))

# Specify the directory to save the resized image
save_directory = "/content/sample_data"

# Create the directory if it doesn't exist
os.makedirs(save_directory, exist_ok=True)

# Save the resized image
resized_img.save(os.path.join(save_directory, "resized_image.jpg"))

# %%
list_images_sample = [
    "/content/sample_data/Viral Pneumonia-13.png",
    "/content/sample_data/Normal-13.png",
    "/content/sample_data/Lung_Opacity-13.png",
    "/content/sample_data/COVID-13.png"
]

# %%
fig, axes = plt.subplots(1, len(list_images_sample), figsize=(12, 4))

for ax, img_path in zip(axes, list_images_sample):
    img = Image.open(img_path)
    ax.imshow(img, cmap="gray")  # Set the colormap to "gray"
    ax.axis("off")
    ax.set_title(img_path)

plt.show()

# %%
model_builder = keras.applications.inception_v3.InceptionV3
img_size = (299, 299)
preprocess_input = keras.applications.inception_v3.preprocess_input
decode_predictions = keras.applications.inception_v3.decode_predictions
imag = []

last_conv_layer_name = "mixed10"

# %%
# To Get Image into numpy array

def get_img_array(img_path, size):
    img = keras.preprocessing.image.load_img(img_path, target_size = size)
    array = keras.preprocessing.image.img_to_array(img)
    array = np.expand_dims(array, axis = 0)
    return array

# Top create heatmaps for the samples

def make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index = None):
    grad_model = tf.keras.models.Model([model.inputs], [model.get_layer(last_conv_layer_name).output, model.output])

    with tf.GradientTape() as tape:
        last_conv_layer_output, preds = grad_model(img_array)
        if pred_index is None:
            pred_index = tf.argmax(preds[0])
        class_channel = preds[:, pred_index]

    grads = tape.gradient(class_channel, last_conv_layer_output)
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

    last_conv_layer_output = last_conv_layer_output[0]
    heatmap = last_conv_layer_output @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)
    heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
    return heatmap.numpy()

# %%
# Storing Heatmap values into list

covid_noncovid_heatmap = []

for i in list_images_sample:
    img_array = preprocess_input(get_img_array(i, size = img_size))
    model = model_builder(weights = "imagenet")
    model.layers[-1].activation = None
    preds = model.predict(img_array)
    heatmap = make_gradcam_heatmap(img_array, model, last_conv_layer_name)
    covid_noncovid_heatmap.append(heatmap)
# Out:
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step

# %%
# To Display GradCAM output for the samples

def save_and_display_gradcam(img_path, heatmap, cam_path = "cam.jpg", alpha = 0.4):
    img = keras.preprocessing.image.load_img(img_path)
    img = keras.preprocessing.image.img_to_array(img)

    heatmap = np.uint8(255 * heatmap)

    jet = cm.get_cmap("jet")
    jet_colors = jet(np.arange(256))[:, :3]
    jet_heatmap = jet_colors[heatmap]
    jet_heatmap = keras.preprocessing.image.array_to_img(jet_heatmap)
    jet_heatmap = jet_heatmap.resize((img.shape[1], img.shape[0]))
    jet_heatmap = keras.preprocessing.image.img_to_array(jet_heatmap)

    superimposed_img = jet_heatmap * alpha + img
    superimposed_img = keras.preprocessing.image.array_to_img(superimposed_img)
    superimposed_img.save(cam_path)

    imag.append(cv2.imread(img_path))
    imag.append(cv2.imread("./cam.jpg"))


for i in range(len(list_images_sample)):
    save_and_display_gradcam(list_images_sample[i], covid_noncovid_heatmap[i])

# %%
def plot_multiple_img(img_matrix_list, title_list, ncols, main_title = ""):

    fig, myaxes = plt.subplots(figsize = (15, 8), nrows = 2, ncols = ncols, squeeze = False)
    fig.suptitle(main_title, fontsize = 18)
    fig.subplots_adjust(wspace = 0.3)
    fig.subplots_adjust(hspace = 0.3)

    for i, (img, title) in enumerate(zip(img_matrix_list, title_list)):
        myaxes[i // ncols][i % ncols].imshow(img)
        myaxes[i // ncols][i % ncols].set_title(title, fontsize = 15)

    plt.show()

# %%
# list_images_sample = ["/kaggle/input/covid19-radiography-database/COVID-19_Radiography_Dataset/Viral Pneumonia/images/Viral Pneumonia-1003.png",
#                      "/kaggle/input/covid19-radiography-database/COVID-19_Radiography_Dataset/Normal/images/Normal-10004.png",
#                      "/kaggle/input/covid19-radiography-database/COVID-19_Radiography_Dataset/Lung_Opacity/images/Lung_Opacity-1000.png",
#                      "/kaggle/input/covid19-radiography-database/COVID-19_Radiography_Dataset/COVID/images/COVID-1008.png"]

titles_list = ["Viral Pneumonia",'Viral Pneumonia Grad','Normal','Normal Grad','Lung_Opacity','Lung_Opacity Grad','COVID','COVID Grad']

plot_multiple_img(imag, titles_list, ncols = 4, main_title = "GRAD-CAM COVID-19 Image Analysis")

# %%
from tensorflow.keras.applications import EfficientNetB7

# %%
efficientnetB7= EfficientNetB7(include_top=False,weights='imagenet',input_shape=(image_size, image_size, 3))
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb7_notop.h5
# 258076736/258076736 [==============================] - 9s 0us/step

# %%
# Output of model

model3 = inceptionv3.output
model3 = tf.keras.layers.GlobalAveragePooling2D()(model3)
model3 = tf.keras.layers.Dropout(0.5)(model3)
model3 = tf.keras.layers.Dense(4, activation='softmax')(model3)
model3 = tf.keras.models.Model(inputs=inceptionv3.input, outputs=model3)

# %%
model3.compile( optimizer='adam',
    loss='categorical_crossentropy',
    metrics=METRICS)

# %%
history3 = model3.load_weights('/content/drive/MyDrive/InceptionV3.h5')

# %%
history3=model3.fit(xtrain,ytrain,epochs=50,validation_data=(xtest,ytest))
# Out:
# Epoch 1/50
# 530/530 [==============================] - 85s 100ms/step - loss: 0.3479 - accuracy: 0.9453 - precision: 0.8997 - recall: 0.8790 - auc: 0.9784 - val_loss: 0.5281 - val_accuracy: 0.9162 - val_precision: 0.8389 - val_recall: 0.8226 - val_auc: 0.9597
# Epoch 2/50
# 530/530 [==============================] - 49s 92ms/step - loss: 0.2326 - accuracy: 0.9595 - precision: 0.9229 - recall: 0.9143 - auc: 0.9885 - val_loss: 0.2685 - val_accuracy: 0.9555 - val_precision: 0.9156 - val_recall: 0.9057 - val_auc: 0.9850
# Epoch 3/50
# 530/530 [==============================] - 48s 91ms/step - loss: 0.1769 - accuracy: 0.9696 - precision: 0.9411 - recall: 0.9370 - auc: 0.9929 - val_loss: 0.3443 - val_accuracy: 0.9379 - val_precision: 0.8842 - val_recall: 0.8646 - val_auc: 0.9772
# Epoch 4/50
# 530/530 [==============================] - 48s 91ms/step - loss: 0.1610 - accuracy: 0.9718 - precision: 0.9453 - recall: 0.9418 - auc: 0.9940 - val_loss: 0.1814 - val_accuracy: 0.9693 - val_precision: 0.9410 - val_recall: 0.9358 - val_auc: 0.9930
# Epoch 5/50
# 530/530 [==============================] - 48s 91ms/step - loss: 0.1354 - accuracy: 0.9758 - precision: 0.9526 - recall: 0.9504 - auc: 0.9956 - val_loss: 0.3886 - val_accuracy: 0.9469 - val_precision: 0.8950 - val_recall: 0.8925 - val_auc: 0.9753
# Epoch 6/50
# 530/530 [==============================] - 48s 91ms/step - loss: 0.1212 - accuracy: 0.9785 - precision: 0.9584 - recall: 0.9555 - auc: 0.9964 - val_loss: 0.4917 - val_accuracy: 0.9216 - val_precision: 0.8488 - val_recall: 0.8354 - val_auc: 0.9662
# Epoch 7/50
# 530/530 [==============================] - 48s 92ms/step - loss: 0.1109 - accuracy: 0.9809 - precision: 0.9628 - recall: 0.9608 - auc: 0.9966 - val_loss: 0.2356 - val_accuracy: 0.9619 - val_precision: 0.9258 - val_recall: 0.9212 - val_auc: 0.9888
# Epoch 8/50
# 530/530 [==============================] - 48s 91ms/step - loss: 0.0843 - accuracy: 0.9854 - precision: 0.9714 - recall: 0.9701 - auc: 0.9979 - val_loss: 0.3764 - val_accuracy: 0.9450 - val_precision: 0.8932 - val_recall: 0.8861 - val_auc: 0.9778
# Epoch 9/50
# 530/530 [==============================] - 49s 92ms/step - loss: 0.0864 - accuracy: 0.9850 - precision: 0.9706 - recall: 0.9693 - auc: 0.9977 - val_loss: 0.3825 - val_accuracy: 0.9384 - val_precision: 0.8783 - val_recall: 0.8748 - val_auc: 0.9770
# Epoch 10/50
# 530/530 [==============================] - 49s 92ms/step - loss: 0.0693 - accuracy: 0.9877 - precision: 0.9761 - recall: 0.9748 - auc: 0.9985 - val_loss: 0.4291 - val_accuracy: 0.9453 - val_precision: 0.8917 - val_recall: 0.8892 - val_auc: 0.9736
# Epoch 11/50
# 530/530 [==============================] - 49s 92ms/step - loss: 0.0619 - accuracy: 0.9899 - precision: 0.9802 - recall: 0.9793 - auc: 0.9987 - val_loss: 0.2464 - val_accuracy: 0.9669 - val_precision: 0.9356 - val_recall: 0.9316 - val_auc: 0.9868
# Epoch 12/50
# 530/530 [==============================] - 48s 91ms/step - loss: 0.0597 - accuracy: 0.9898 - precision: 0.9798 - recall: 0.9792 - auc: 0.9989 - val_loss: 0.4192 - val_accuracy: 0.9588 - val_precision: 0.9181 - val_recall: 0.9172 - val_auc: 0.9771
# Epoch 13/50
# 530/530 [==============================] - 48s 91ms/step - loss: 0.0434 - accuracy: 0.9930 - precision: 0.9863 - recall: 0.9857 - auc: 0.9991 - val_loss: 0.4037 - val_accuracy: 0.9557 - val_precision: 0.9133 - val_recall: 0.9090 - val_auc: 0.9759
# Epoch 14/50
# 530/530 [==============================] - 48s 91ms/step - loss: 0.0420 - accuracy: 0.9930 - precision: 0.9862 - recall: 0.9859 - auc: 0.9991 - val_loss: 0.6469 - val_accuracy: 0.9370 - val_precision: 0.8760 - val_recall: 0.8712 - val_auc: 0.9604
# Epoch 15/50
# 530/530 [==============================] - 48s 91ms/step - loss: 0.0357 - accuracy: 0.9940 - precision: 0.9883 - recall: 0.9879 - auc: 0.9994 - val_loss: 0.3973 - val_accuracy: 0.9540 - val_precision: 0.9096 - val_recall: 0.9061 - val_auc: 0.9765
# Epoch 16/50
# 530/530 [==============================] - 48s 91ms/step - loss: 0.0476 - accuracy: 0.9924 - precision: 0.9852 - recall: 0.9846 - auc: 0.9989 - val_loss: 0.4041 - val_accuracy: 0.9401 - val_precision: 0.8842 - val_recall: 0.8750 - val_auc: 0.9740
# Epoch 17/50
# 530/530 [==============================] - 48s 91ms/step - loss: 0.0302 - accuracy: 0.9948 - precision: 0.9898 - recall: 0.9893 - auc: 0.9995 - val_loss: 0.2587 - val_accuracy: 0.9713 - val_precision: 0.9429 - val_recall: 0.9422 - val_auc: 0.9865
# Epoch 18/50
# 530/530 [==============================] - 48s 91ms/step - loss: 0.0356 - accuracy: 0.9938 - precision: 0.9877 - recall: 0.9874 - auc: 0.9995 - val_loss: 0.2895 - val_accuracy: 0.9679 - val_precision: 0.9367 - val_recall: 0.9349 - val_auc: 0.9841
# Epoch 19/50
# 530/530 [==============================] - 48s 91ms/step - loss: 0.0270 - accuracy: 0.9952 - precision: 0.9906 - recall: 0.9902 - auc: 0.9998 - val_loss: 0.2851 - val_accuracy: 0.9730 - val_precision: 0.9466 - val_recall: 0.9453 - val_auc: 0.9844
# Epoch 20/50
# 530/530 [==============================] - 48s 91ms/step - loss: 0.0264 - accuracy: 0.9955 - precision: 0.9912 - recall: 0.9909 - auc: 0.9995 - val_loss: 0.3356 - val_accuracy: 0.9647 - val_precision: 0.9301 - val_recall: 0.9288 - val_auc: 0.9814
# Epoch 21/50
# 530/530 [==============================] - 48s 91ms/step - loss: 0.0311 - accuracy: 0.9946 - precision: 0.9894 - recall: 0.9890 - auc: 0.9996 - val_loss: 0.2513 - val_accuracy: 0.9665 - val_precision: 0.9338 - val_recall: 0.9321 - val_auc: 0.9875
# Epoch 22/50
# 530/530 [==============================] - 48s 91ms/step - loss: 0.0194 - accuracy: 0.9968 - precision: 0.9937 - recall: 0.9935 - auc: 0.9997 - val_loss: 0.4251 - val_accuracy: 0.9604 - val_precision: 0.9217 - val_recall: 0.9196 - val_auc: 0.9786
# Epoch 23/50
# 530/530 [==============================] - 48s 91ms/step - loss: 0.0236 - accuracy: 0.9963 - precision: 0.9927 - recall: 0.9925 - auc: 0.9996 - val_loss: 0.5301 - val_accuracy: 0.9320 - val_precision: 0.8679 - val_recall: 0.8585 - val_auc: 0.9648
# Epoch 24/50
# 530/530 [==============================] - 48s 91ms/step - loss: 0.0266 - accuracy: 0.9957 - precision: 0.9915 - recall: 0.9911 - auc: 0.9996 - val_loss: 0.3270 - val_accuracy: 0.9646 - val_precision: 0.9302 - val_recall: 0.9278 - val_auc: 0.9809
# Epoch 25/50
# 530/530 [==============================] - 49s 92ms/step - loss: 0.0239 - accuracy: 0.9959 - precision: 0.9919 - recall: 0.9919 - auc: 0.9996 - val_loss: 0.4742 - val_accuracy: 0.9522 - val_precision: 0.9056 - val_recall: 0.9031 - val_auc: 0.9733
# Epoch 26/50
# 530/530 [==============================] - 48s 91ms/step - loss: 0.0191 - accuracy: 0.9967 - precision: 0.9935 - recall: 0.9934 - auc: 0.9997 - val_loss: 0.3764 - val_accuracy: 0.9616 - val_precision: 0.9241 - val_recall: 0.9219 - val_auc: 0.9797
# Epoch 27/50
# 530/530 [==============================] - 49s 92ms/step - loss: 0.0179 - accuracy: 0.9972 - precision: 0.9944 - recall: 0.9943 - auc: 0.9996 - val_loss: 0.3195 - val_accuracy: 0.9650 - val_precision: 0.9306 - val_recall: 0.9292 - val_auc: 0.9823
# Epoch 28/50
# 530/530 [==============================] - 48s 91ms/step - loss: 0.0249 - accuracy: 0.9958 - precision: 0.9916 - recall: 0.9914 - auc: 0.9996 - val_loss: 0.2816 - val_accuracy: 0.9722 - val_precision: 0.9450 - val_recall: 0.9436 - val_auc: 0.9851
# Epoch 29/50
# 530/530 [==============================] - 49s 92ms/step - loss: 0.0169 - accuracy: 0.9972 - precision: 0.9945 - recall: 0.9944 - auc: 0.9997 - val_loss: 0.3888 - val_accuracy: 0.9694 - val_precision: 0.9391 - val_recall: 0.9384 - val_auc: 0.9772
# Epoch 30/50
# 530/530 [==============================] - 49s 92ms/step - loss: 0.0205 - accuracy: 0.9966 - precision: 0.9934 - recall: 0.9932 - auc: 0.9996 - val_loss: 0.5919 - val_accuracy: 0.9613 - val_precision: 0.9228 - val_recall: 0.9224 - val_auc: 0.9715
# Epoch 31/50
# 530/530 [==============================] - 48s 91ms/step - loss: 0.0163 - accuracy: 0.9973 - precision: 0.9947 - recall: 0.9947 - auc: 0.9998 - val_loss: 0.4882 - val_accuracy: 0.9488 - val_precision: 0.8995 - val_recall: 0.8953 - val_auc: 0.9724
# Epoch 32/50
# 530/530 [==============================] - 48s 91ms/step - loss: 0.0115 - accuracy: 0.9979 - precision: 0.9959 - recall: 0.9958 - auc: 0.9999 - val_loss: 0.6350 - val_accuracy: 0.9368 - val_precision: 0.8739 - val_recall: 0.8731 - val_auc: 0.9618
# Epoch 33/50
# 530/530 [==============================] - 48s 91ms/step - loss: 0.0201 - accuracy: 0.9968 - precision: 0.9937 - recall: 0.9936 - auc: 0.9996 - val_loss: 0.2246 - val_accuracy: 0.9740 - val_precision: 0.9481 - val_recall: 0.9479 - val_auc: 0.9881
# Epoch 34/50
# 530/530 [==============================] - 48s 91ms/step - loss: 0.0101 - accuracy: 0.9981 - precision: 0.9962 - recall: 0.9961 - auc: 0.9999 - val_loss: 0.4343 - val_accuracy: 0.9630 - val_precision: 0.9267 - val_recall: 0.9250 - val_auc: 0.9785
# Epoch 35/50
# 530/530 [==============================] - 48s 91ms/step - loss: 0.0161 - accuracy: 0.9975 - precision: 0.9950 - recall: 0.9949 - auc: 0.9997 - val_loss: 0.5081 - val_accuracy: 0.9530 - val_precision: 0.9063 - val_recall: 0.9057 - val_auc: 0.9724
# Epoch 36/50
# 530/530 [==============================] - 48s 91ms/step - loss: 0.0222 - accuracy: 0.9963 - precision: 0.9927 - recall: 0.9925 - auc: 0.9996 - val_loss: 0.3160 - val_accuracy: 0.9676 - val_precision: 0.9353 - val_recall: 0.9349 - val_auc: 0.9842
# Epoch 37/50
# 530/530 [==============================] - 48s 91ms/step - loss: 0.0140 - accuracy: 0.9977 - precision: 0.9954 - recall: 0.9952 - auc: 0.9999 - val_loss: 0.3705 - val_accuracy: 0.9644 - val_precision: 0.9288 - val_recall: 0.9288 - val_auc: 0.9808
# Epoch 38/50
# 530/530 [==============================] - 48s 91ms/step - loss: 0.0101 - accuracy: 0.9985 - precision: 0.9969 - recall: 0.9969 - auc: 0.9998 - val_loss: 0.3849 - val_accuracy: 0.9685 - val_precision: 0.9374 - val_recall: 0.9366 - val_auc: 0.9810
# Epoch 39/50
# 530/530 [==============================] - 48s 91ms/step - loss: 0.0131 - accuracy: 0.9975 - precision: 0.9951 - recall: 0.9950 - auc: 0.9999 - val_loss: 0.4234 - val_accuracy: 0.9571 - val_precision: 0.9150 - val_recall: 0.9134 - val_auc: 0.9754
# Epoch 40/50
# 530/530 [==============================] - 49s 92ms/step - loss: 0.0190 - accuracy: 0.9972 - precision: 0.9945 - recall: 0.9943 - auc: 0.9996 - val_loss: 0.2596 - val_accuracy: 0.9739 - val_precision: 0.9479 - val_recall: 0.9479 - val_auc: 0.9858
# Epoch 41/50
# 530/530 [==============================] - 48s 91ms/step - loss: 0.0125 - accuracy: 0.9982 - precision: 0.9963 - recall: 0.9963 - auc: 0.9997 - val_loss: 0.3061 - val_accuracy: 0.9715 - val_precision: 0.9429 - val_recall: 0.9429 - val_auc: 0.9836
# Epoch 42/50
# 530/530 [==============================] - 48s 91ms/step - loss: 0.0098 - accuracy: 0.9984 - precision: 0.9969 - recall: 0.9967 - auc: 0.9998 - val_loss: 0.3737 - val_accuracy: 0.9631 - val_precision: 0.9270 - val_recall: 0.9252 - val_auc: 0.9803
# Epoch 43/50
# 530/530 [==============================] - 49s 92ms/step - loss: 0.0136 - accuracy: 0.9979 - precision: 0.9958 - recall: 0.9958 - auc: 0.9997 - val_loss: 0.3175 - val_accuracy: 0.9726 - val_precision: 0.9457 - val_recall: 0.9446 - val_auc: 0.9855
# Epoch 44/50
# 530/530 [==============================] - 49s 92ms/step - loss: 0.0285 - accuracy: 0.9956 - precision: 0.9913 - recall: 0.9912 - auc: 0.9994 - val_loss: 0.5205 - val_accuracy: 0.9574 - val_precision: 0.9154 - val_recall: 0.9142 - val_auc: 0.9748
# Epoch 45/50
# 530/530 [==============================] - 49s 92ms/step - loss: 0.0081 - accuracy: 0.9987 - precision: 0.9973 - recall: 0.9973 - auc: 0.9999 - val_loss: 0.3513 - val_accuracy: 0.9616 - val_precision: 0.9237 - val_recall: 0.9224 - val_auc: 0.9813
# Epoch 46/50
# 530/530 [==============================] - 49s 92ms/step - loss: 0.0094 - accuracy: 0.9983 - precision: 0.9967 - recall: 0.9966 - auc: 0.9999 - val_loss: 0.3924 - val_accuracy: 0.9674 - val_precision: 0.9351 - val_recall: 0.9344 - val_auc: 0.9787
# Epoch 47/50
# 530/530 [==============================] - 48s 91ms/step - loss: 0.0118 - accuracy: 0.9980 - precision: 0.9962 - recall: 0.9960 - auc: 0.9997 - val_loss: 0.3896 - val_accuracy: 0.9577 - val_precision: 0.9157 - val_recall: 0.9151 - val_auc: 0.9781
# Epoch 48/50
# 530/530 [==============================] - 49s 92ms/step - loss: 0.0126 - accuracy: 0.9980 - precision: 0.9959 - recall: 0.9959 - auc: 0.9998 - val_loss: 0.5496 - val_accuracy: 0.9577 - val_precision: 0.9159 - val_recall: 0.9149 - val_auc: 0.9719
# Epoch 49/50
# 530/530 [==============================] - 49s 92ms/step - loss: 0.0115 - accuracy: 0.9984 - precision: 0.9968 - recall: 0.9967 - auc: 0.9998 - val_loss: 0.3725 - val_accuracy: 0.9735 - val_precision: 0.9474 - val_recall: 0.9465 - val_auc: 0.9824
# Epoch 50/50
# 530/530 [==============================] - 49s 92ms/step - loss: 0.0121 - accuracy: 0.9979 - precision: 0.9958 - recall: 0.9956 - auc: 0.9999 - val_loss: 0.5532 - val_accuracy: 0.9695 - val_precision: 0.9393 - val_recall: 0.9387 - val_auc: 0.9776

# %%
history3 = model3.load_weights('/content/sample_data/InceptionV3.h5')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-f401868c96c9> in <cell line: 1>()
# ----> 1 history2 = model2.load_weights('/content/drive/MyDrive/efficientb7.h5')
#
# /usr/local/lib/python3.10/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/backend.py in _assign_value_to_variable(variable, value)
#    4358     else:
#    4359         # For the normal tf.Variable assign
# -> 4360         variable.assign(value)
#    4361
#    4362
#
# ValueError: Cannot assign value to variable ' dense_8/kernel:0': Shape mismatch.The variable shape (2560, 4), and the assigned value shape (2560, 5) are incompatible.

# %%
import pickle

with open('/content/drive/MyDrive/efficientb7_history.pkl', 'rb') as f:
    history2 = pickle.load(f)

# %%
pred3 = model3.predict(xtest)
pred3 = np.argmax(pred3, axis=1)
actual_label3 = np.argmax(ytest, axis=1)
print(classification_report(actual_label3, pred3,target_names = labels))
# Out:
# 133/133 [==============================] - 13s 72ms/step
#                  precision    recall  f1-score   support
#
#           COVID       0.98      0.97      0.98       733
#          Normal       0.90      0.99      0.94      2057
#    Lung_Opacity       0.98      0.84      0.90      1152
# Viral Pneumonia       0.99      0.92      0.95       298
#
#        accuracy                           0.94      4240
#       macro avg       0.96      0.93      0.94      4240
#    weighted avg       0.94      0.94      0.94      4240

# %%
accuracy_score(actual_label3, pred3)
# Out:
# 0.9389150943396226

# %%
Cm2=confusion_matrix(actual_label3,pred3)
ax2=plt.axes()
sns.heatmap(Cm2, cmap='Blues' ,annot=True,fmt='d',
           annot_kws={'size':10},
           xticklabels=labels,
           yticklabels=labels,
           ax=ax2
           )

plt.title("Confusion Matrix for Covid-19 detection using Inception-v3")
plt.savefig('netb7_confusion.png', dpi=300) # Save plot as PNG
plt.show()

# %%
# Plot the training and validation accuracy
plt.plot(history3.history['accuracy'])
plt.plot(history3.history['val_accuracy'])
plt.title('Inception-v3 Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Training', 'Validation'])
plt.savefig('Inception-v3.png', dpi=300) # Save plot as PNG
plt.show()

# Plot the training and validation loss
plt.plot(history3.history['loss'])
plt.plot(history3.history['val_loss'])
plt.title('Inception-v3 Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Training', 'Validation'])
plt.savefig('Inception-v3.png', dpi=300) # Save plot as PNG
plt.show()

# %%
# Plot the training and validation auc
plt.plot(history3.history['auc'])
plt.plot(history3.history['val_auc'])
plt.title('Inception-v3 Model AUC')
plt.xlabel('Epoch')
plt.ylabel('AUC')
plt.legend(['Training', 'Validation'])
plt.savefig('InceptionV3_auc.png', dpi=300) # Save plot as PNG

plt.show()

# Plot the training and validation precision
plt.plot(history3.history['precision'])
plt.plot(history3.history['val_precision'])
plt.title('Inception-v3 Model Precision')
plt.xlabel('Epoch')
plt.ylabel('Precision')
plt.legend(['Training', 'Validation'])
plt.savefig('InceptionV3_precision.png', dpi=300) # Save plot as PNG
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-2ae4d0201ba4> in <cell line: 2>()
#       1 # Plot the training and validation auc
# ----> 2 plt.plot(history3.history['auc'])
#       3 plt.plot(history3.history['val_auc'])
#       4 plt.title('Inception-v3 Model AUC')
#       5 plt.xlabel('Epoch')
#
# NameError: name 'history3' is not defined

# %%
import pandas as pd

# Assuming 'history1' is the History object returned from model.fit()
metrics = pd.DataFrame(history3.history)

# Save the training history to a CSV file
metrics.to_csv('/content/sample_data/InceptionV3.csv', index=False)

# Save the model itself
model3.save('/content/sample_data/InceptionV3.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# # VGG19 MODEL

# %%
from tensorflow.keras.applications.vgg19 import VGG19
vgg = VGG19(weights='imagenet',
            include_top = False,input_shape=(image_size, image_size, 3)
           )
for layer in vgg.layers:
    layer.trainable = False
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Flatten,Dense
model4 = Sequential()
model4.add(vgg)
model4.add(Flatten())
model4.add(Dense(4,activation="softmax"))
#model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 0s 0us/step

# %% [markdown]
# ## Compile VGG19 Model

# %%
model4.compile( optimizer='adam',
    loss='categorical_crossentropy',
    metrics=METRICS)

# %%
history4=model4.load_weights('/content/sample_data/VGG.h5')

# %%
history4=model4.fit(xtrain,ytrain,epochs=50,validation_data=(xtest,ytest))
# Out:
# Epoch 1/50
# 530/530 [==============================] - 117s 210ms/step - loss: 4.2960 - accuracy: 0.9476 - precision: 0.8954 - recall: 0.8949 - auc: 0.9419 - val_loss: 5.0344 - val_accuracy: 0.9114 - val_precision: 0.8229 - val_recall: 0.8229 - val_auc: 0.8974
# Epoch 2/50
# 530/530 [==============================] - 102s 193ms/step - loss: 2.6120 - accuracy: 0.9560 - precision: 0.9121 - recall: 0.9121 - auc: 0.9503 - val_loss: 3.7872 - val_accuracy: 0.9512 - val_precision: 0.9024 - val_recall: 0.9024 - val_auc: 0.9419
# Epoch 3/50
# 530/530 [==============================] - 102s 193ms/step - loss: 1.7259 - accuracy: 0.9669 - precision: 0.9339 - recall: 0.9339 - auc: 0.9641 - val_loss: 4.6044 - val_accuracy: 0.9402 - val_precision: 0.8804 - val_recall: 0.8804 - val_auc: 0.9281
# Epoch 4/50
# 530/530 [==============================] - 102s 193ms/step - loss: 1.3349 - accuracy: 0.9748 - precision: 0.9497 - recall: 0.9497 - auc: 0.9722 - val_loss: 7.3396 - val_accuracy: 0.9355 - val_precision: 0.8710 - val_recall: 0.8710 - val_auc: 0.9194
# Epoch 5/50
# 530/530 [==============================] - 102s 192ms/step - loss: 1.3390 - accuracy: 0.9752 - precision: 0.9504 - recall: 0.9504 - auc: 0.9721 - val_loss: 5.0348 - val_accuracy: 0.9504 - val_precision: 0.9007 - val_recall: 0.9007 - val_auc: 0.9418
# Epoch 6/50
# 530/530 [==============================] - 102s 192ms/step - loss: 0.9686 - accuracy: 0.9819 - precision: 0.9639 - recall: 0.9639 - auc: 0.9792 - val_loss: 6.1404 - val_accuracy: 0.9499 - val_precision: 0.9000 - val_recall: 0.8998 - val_auc: 0.9388
# Epoch 7/50
# 530/530 [==============================] - 102s 193ms/step - loss: 0.8798 - accuracy: 0.9841 - precision: 0.9682 - recall: 0.9682 - auc: 0.9824 - val_loss: 6.6622 - val_accuracy: 0.9449 - val_precision: 0.8899 - val_recall: 0.8899 - val_auc: 0.9310
# Epoch 8/50
# 530/530 [==============================] - 102s 192ms/step - loss: 0.6570 - accuracy: 0.9871 - precision: 0.9742 - recall: 0.9742 - auc: 0.9857 - val_loss: 6.7422 - val_accuracy: 0.9525 - val_precision: 0.9050 - val_recall: 0.9050 - val_auc: 0.9406
# Epoch 9/50
# 530/530 [==============================] - 102s 192ms/step - loss: 0.7393 - accuracy: 0.9863 - precision: 0.9726 - recall: 0.9725 - auc: 0.9853 - val_loss: 8.3946 - val_accuracy: 0.9460 - val_precision: 0.8920 - val_recall: 0.8920 - val_auc: 0.9327
# Epoch 10/50
# 530/530 [==============================] - 102s 192ms/step - loss: 0.6442 - accuracy: 0.9884 - precision: 0.9769 - recall: 0.9769 - auc: 0.9867 - val_loss: 7.4705 - val_accuracy: 0.9491 - val_precision: 0.8981 - val_recall: 0.8981 - val_auc: 0.9362
# Epoch 11/50
# 530/530 [==============================] - 102s 192ms/step - loss: 0.9471 - accuracy: 0.9856 - precision: 0.9713 - recall: 0.9713 - auc: 0.9831 - val_loss: 6.9787 - val_accuracy: 0.9570 - val_precision: 0.9139 - val_recall: 0.9139 - val_auc: 0.9473
# Epoch 12/50
# 530/530 [==============================] - 102s 192ms/step - loss: 0.5385 - accuracy: 0.9902 - precision: 0.9805 - recall: 0.9805 - auc: 0.9892 - val_loss: 9.1105 - val_accuracy: 0.9513 - val_precision: 0.9026 - val_recall: 0.9026 - val_auc: 0.9383
# Epoch 13/50
# 530/530 [==============================] - 102s 193ms/step - loss: 0.6000 - accuracy: 0.9906 - precision: 0.9812 - recall: 0.9812 - auc: 0.9890 - val_loss: 8.4126 - val_accuracy: 0.9507 - val_precision: 0.9014 - val_recall: 0.9014 - val_auc: 0.9377
# Epoch 14/50
# 530/530 [==============================] - 102s 193ms/step - loss: 0.4619 - accuracy: 0.9918 - precision: 0.9836 - recall: 0.9836 - auc: 0.9905 - val_loss: 8.4581 - val_accuracy: 0.9554 - val_precision: 0.9108 - val_recall: 0.9108 - val_auc: 0.9432
# Epoch 15/50
# 530/530 [==============================] - 102s 192ms/step - loss: 0.6860 - accuracy: 0.9895 - precision: 0.9790 - recall: 0.9790 - auc: 0.9875 - val_loss: 8.3507 - val_accuracy: 0.9571 - val_precision: 0.9142 - val_recall: 0.9142 - val_auc: 0.9457
# Epoch 16/50
# 530/530 [==============================] - 102s 192ms/step - loss: 0.3846 - accuracy: 0.9933 - precision: 0.9867 - recall: 0.9867 - auc: 0.9924 - val_loss: 8.6492 - val_accuracy: 0.9559 - val_precision: 0.9118 - val_recall: 0.9118 - val_auc: 0.9447
# Epoch 17/50
# 530/530 [==============================] - 102s 193ms/step - loss: 0.7664 - accuracy: 0.9904 - precision: 0.9808 - recall: 0.9808 - auc: 0.9888 - val_loss: 8.9927 - val_accuracy: 0.9592 - val_precision: 0.9184 - val_recall: 0.9184 - val_auc: 0.9485
# Epoch 18/50
# 530/530 [==============================] - 102s 192ms/step - loss: 0.5580 - accuracy: 0.9917 - precision: 0.9834 - recall: 0.9834 - auc: 0.9904 - val_loss: 10.1510 - val_accuracy: 0.9554 - val_precision: 0.9108 - val_recall: 0.9108 - val_auc: 0.9431
# Epoch 19/50
# 530/530 [==============================] - 102s 192ms/step - loss: 0.5353 - accuracy: 0.9931 - precision: 0.9863 - recall: 0.9863 - auc: 0.9919 - val_loss: 12.1187 - val_accuracy: 0.9500 - val_precision: 0.9000 - val_recall: 0.9000 - val_auc: 0.9366
# Epoch 20/50
# 530/530 [==============================] - 102s 192ms/step - loss: 0.2605 - accuracy: 0.9953 - precision: 0.9905 - recall: 0.9905 - auc: 0.9948 - val_loss: 9.6055 - val_accuracy: 0.9548 - val_precision: 0.9097 - val_recall: 0.9097 - val_auc: 0.9432
# Epoch 21/50
# 530/530 [==============================] - 102s 192ms/step - loss: 0.2861 - accuracy: 0.9953 - precision: 0.9906 - recall: 0.9906 - auc: 0.9944 - val_loss: 10.1045 - val_accuracy: 0.9565 - val_precision: 0.9130 - val_recall: 0.9130 - val_auc: 0.9438
# Epoch 22/50
# 530/530 [==============================] - 102s 193ms/step - loss: 0.4599 - accuracy: 0.9934 - precision: 0.9868 - recall: 0.9868 - auc: 0.9926 - val_loss: 11.7281 - val_accuracy: 0.9382 - val_precision: 0.8764 - val_recall: 0.8764 - val_auc: 0.9209
# Epoch 23/50
# 530/530 [==============================] - 102s 192ms/step - loss: 0.2843 - accuracy: 0.9957 - precision: 0.9914 - recall: 0.9914 - auc: 0.9950 - val_loss: 13.5878 - val_accuracy: 0.9483 - val_precision: 0.8967 - val_recall: 0.8967 - val_auc: 0.9331
# Epoch 24/50
# 530/530 [==============================] - 102s 193ms/step - loss: 0.4248 - accuracy: 0.9950 - precision: 0.9901 - recall: 0.9901 - auc: 0.9942 - val_loss: 10.3922 - val_accuracy: 0.9551 - val_precision: 0.9101 - val_recall: 0.9101 - val_auc: 0.9427
# Epoch 25/50
# 530/530 [==============================] - 102s 193ms/step - loss: 0.3577 - accuracy: 0.9951 - precision: 0.9902 - recall: 0.9902 - auc: 0.9940 - val_loss: 11.4458 - val_accuracy: 0.9538 - val_precision: 0.9075 - val_recall: 0.9075 - val_auc: 0.9408
# Epoch 26/50
# 530/530 [==============================] - 102s 192ms/step - loss: 0.2986 - accuracy: 0.9958 - precision: 0.9916 - recall: 0.9916 - auc: 0.9952 - val_loss: 13.4481 - val_accuracy: 0.9520 - val_precision: 0.9040 - val_recall: 0.9040 - val_auc: 0.9387
# Epoch 27/50
# 530/530 [==============================] - 102s 192ms/step - loss: 0.5368 - accuracy: 0.9932 - precision: 0.9864 - recall: 0.9864 - auc: 0.9918 - val_loss: 11.9150 - val_accuracy: 0.9538 - val_precision: 0.9075 - val_recall: 0.9075 - val_auc: 0.9406
# Epoch 28/50
# 530/530 [==============================] - 103s 194ms/step - loss: 0.2604 - accuracy: 0.9963 - precision: 0.9925 - recall: 0.9925 - auc: 0.9958 - val_loss: 13.6915 - val_accuracy: 0.9478 - val_precision: 0.8955 - val_recall: 0.8955 - val_auc: 0.9329
# Epoch 29/50
# 530/530 [==============================] - 102s 193ms/step - loss: 0.3533 - accuracy: 0.9958 - precision: 0.9916 - recall: 0.9916 - auc: 0.9953 - val_loss: 12.0200 - val_accuracy: 0.9548 - val_precision: 0.9097 - val_recall: 0.9097 - val_auc: 0.9419
# Epoch 30/50
# 530/530 [==============================] - 102s 193ms/step - loss: 0.2170 - accuracy: 0.9966 - precision: 0.9931 - recall: 0.9931 - auc: 0.9960 - val_loss: 13.6167 - val_accuracy: 0.9450 - val_precision: 0.8901 - val_recall: 0.8901 - val_auc: 0.9286
# Epoch 31/50
# 530/530 [==============================] - 102s 192ms/step - loss: 0.3454 - accuracy: 0.9959 - precision: 0.9918 - recall: 0.9918 - auc: 0.9951 - val_loss: 12.6583 - val_accuracy: 0.9545 - val_precision: 0.9090 - val_recall: 0.9090 - val_auc: 0.9404
# Epoch 32/50
# 530/530 [==============================] - 102s 193ms/step - loss: 0.3498 - accuracy: 0.9959 - precision: 0.9919 - recall: 0.9919 - auc: 0.9952 - val_loss: 12.3872 - val_accuracy: 0.9586 - val_precision: 0.9172 - val_recall: 0.9172 - val_auc: 0.9454
# Epoch 33/50
# 530/530 [==============================] - 103s 194ms/step - loss: 0.2375 - accuracy: 0.9965 - precision: 0.9930 - recall: 0.9930 - auc: 0.9960 - val_loss: 13.7846 - val_accuracy: 0.9537 - val_precision: 0.9073 - val_recall: 0.9073 - val_auc: 0.9395
# Epoch 34/50
# 530/530 [==============================] - 102s 193ms/step - loss: 0.3227 - accuracy: 0.9961 - precision: 0.9922 - recall: 0.9922 - auc: 0.9955 - val_loss: 13.7477 - val_accuracy: 0.9539 - val_precision: 0.9078 - val_recall: 0.9078 - val_auc: 0.9402
# Epoch 35/50
# 530/530 [==============================] - 102s 193ms/step - loss: 0.2419 - accuracy: 0.9970 - precision: 0.9940 - recall: 0.9940 - auc: 0.9965 - val_loss: 13.3839 - val_accuracy: 0.9515 - val_precision: 0.9031 - val_recall: 0.9031 - val_auc: 0.9370
# Epoch 36/50
# 530/530 [==============================] - 102s 192ms/step - loss: 0.1710 - accuracy: 0.9972 - precision: 0.9944 - recall: 0.9944 - auc: 0.9970 - val_loss: 14.7303 - val_accuracy: 0.9514 - val_precision: 0.9028 - val_recall: 0.9028 - val_auc: 0.9371
# Epoch 37/50
# 530/530 [==============================] - 102s 193ms/step - loss: 0.4320 - accuracy: 0.9953 - precision: 0.9906 - recall: 0.9906 - auc: 0.9942 - val_loss: 15.1824 - val_accuracy: 0.9491 - val_precision: 0.8981 - val_recall: 0.8981 - val_auc: 0.9353
# Epoch 38/50
# 530/530 [==============================] - 102s 193ms/step - loss: 0.2413 - accuracy: 0.9968 - precision: 0.9937 - recall: 0.9937 - auc: 0.9963 - val_loss: 14.0055 - val_accuracy: 0.9533 - val_precision: 0.9066 - val_recall: 0.9066 - val_auc: 0.9395
# Epoch 39/50
# 530/530 [==============================] - 102s 193ms/step - loss: 0.2951 - accuracy: 0.9970 - precision: 0.9940 - recall: 0.9940 - auc: 0.9965 - val_loss: 13.5469 - val_accuracy: 0.9563 - val_precision: 0.9125 - val_recall: 0.9125 - val_auc: 0.9425
# Epoch 40/50
# 530/530 [==============================] - 102s 192ms/step - loss: 0.1390 - accuracy: 0.9978 - precision: 0.9956 - recall: 0.9956 - auc: 0.9975 - val_loss: 19.1549 - val_accuracy: 0.9448 - val_precision: 0.8896 - val_recall: 0.8896 - val_auc: 0.9281
# Epoch 41/50
# 530/530 [==============================] - 102s 192ms/step - loss: 0.2356 - accuracy: 0.9966 - precision: 0.9932 - recall: 0.9932 - auc: 0.9962 - val_loss: 15.0910 - val_accuracy: 0.9517 - val_precision: 0.9033 - val_recall: 0.9033 - val_auc: 0.9377
# Epoch 42/50
# 530/530 [==============================] - 102s 192ms/step - loss: 0.2119 - accuracy: 0.9970 - precision: 0.9940 - recall: 0.9940 - auc: 0.9967 - val_loss: 15.1056 - val_accuracy: 0.9553 - val_precision: 0.9106 - val_recall: 0.9106 - val_auc: 0.9417
# Epoch 43/50
# 530/530 [==============================] - 102s 192ms/step - loss: 0.2727 - accuracy: 0.9969 - precision: 0.9938 - recall: 0.9938 - auc: 0.9963 - val_loss: 15.4996 - val_accuracy: 0.9567 - val_precision: 0.9134 - val_recall: 0.9134 - val_auc: 0.9432
# Epoch 44/50
# 530/530 [==============================] - 102s 193ms/step - loss: 0.1003 - accuracy: 0.9985 - precision: 0.9969 - recall: 0.9969 - auc: 0.9981 - val_loss: 14.5245 - val_accuracy: 0.9550 - val_precision: 0.9099 - val_recall: 0.9099 - val_auc: 0.9409
# Epoch 45/50
# 530/530 [==============================] - 102s 192ms/step - loss: 0.3381 - accuracy: 0.9963 - precision: 0.9927 - recall: 0.9927 - auc: 0.9954 - val_loss: 15.4379 - val_accuracy: 0.9547 - val_precision: 0.9094 - val_recall: 0.9094 - val_auc: 0.9406
# Epoch 46/50
# 530/530 [==============================] - 102s 193ms/step - loss: 0.1390 - accuracy: 0.9980 - precision: 0.9960 - recall: 0.9960 - auc: 0.9978 - val_loss: 16.7358 - val_accuracy: 0.9499 - val_precision: 0.8998 - val_recall: 0.8998 - val_auc: 0.9355
# Epoch 47/50
# 530/530 [==============================] - 102s 193ms/step - loss: 0.3189 - accuracy: 0.9965 - precision: 0.9930 - recall: 0.9930 - auc: 0.9957 - val_loss: 19.7621 - val_accuracy: 0.9509 - val_precision: 0.9019 - val_recall: 0.9019 - val_auc: 0.9365
# Epoch 48/50
# 530/530 [==============================] - 102s 193ms/step - loss: 0.2271 - accuracy: 0.9976 - precision: 0.9951 - recall: 0.9951 - auc: 0.9970 - val_loss: 20.2722 - val_accuracy: 0.9501 - val_precision: 0.9002 - val_recall: 0.9002 - val_auc: 0.9345
# Epoch 49/50
# 530/530 [==============================] - 102s 192ms/step - loss: 0.1964 - accuracy: 0.9977 - precision: 0.9954 - recall: 0.9954 - auc: 0.9973 - val_loss: 16.0326 - val_accuracy: 0.9545 - val_precision: 0.9090 - val_recall: 0.9090 - val_auc: 0.9409
# Epoch 50/50
# 530/530 [==============================] - 102s 192ms/step - loss: 0.2321 - accuracy: 0.9973 - precision: 0.9947 - recall: 0.9947 - auc: 0.9968 - val_loss: 19.5301 - val_accuracy: 0.9462 - val_precision: 0.8925 - val_recall: 0.8925 - val_auc: 0.9302

# %%
history3 = model3.load_weights('/kaggle/input/model-training/Model Training/vgg19.h5')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-49eaf6dd7d2b> in <cell line: 1>()
# ----> 1 history3 = model3.load_weights('/kaggle/input/model-training/Model Training/vgg19.h5')
#
# NameError: name 'model3' is not defined

# %%
import pickle

with open('/kaggle/input/model-training/Model Training/vgg19_history.pkl', 'rb') as f:
    history3 = pickle.load(f)

# %%
pred4 = model4.predict(xtest)
pred4 = np.argmax(pred4, axis=1)
actual_label4 = np.argmax(ytest, axis=1)
print(classification_report(actual_label4, pred4, target_names = labels))
# Out:
# 133/133 [==============================] - 32s 205ms/step
#                  precision    recall  f1-score   support
#
#           COVID       0.95      0.92      0.94       733
#          Normal       0.94      0.86      0.90      2057
#    Lung_Opacity       0.78      0.91      0.84      1152
# Viral Pneumonia       0.95      0.96      0.95       298
#
#        accuracy                           0.89      4240
#       macro avg       0.91      0.91      0.91      4240
#    weighted avg       0.90      0.89      0.89      4240

# %%
accuracy_score(actual_label4, pred4)
# Out:
# 0.8924528301886793

# %%
Cm3=confusion_matrix(actual_label4,pred4)
ax3=plt.axes()
sns.heatmap(Cm3, cmap='Blues' ,annot=True,fmt='d',
           annot_kws={'size':10},
           xticklabels=labels,
           yticklabels=labels,
           ax=ax3
           )

plt.title("Confusion Matrix for Covid-19 detection using VGG 19")
plt.savefig('vgg19_confusion.png', dpi=300) # Save plot as PNG
plt.show()

# %% [markdown]
# ## Loss and Accuracy Measurement Graph - VGG19 Model

# %%
# Plot the training and validation accuracy
plt.plot(history4.history['accuracy'])
plt.plot(history4.history['val_accuracy'])
plt.title('VGG 19 Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Training', 'Validation'])
plt.savefig('vgg19_accuracy.png', dpi=300) # Save plot as PNG
plt.show()

# Plot the training and validation loss
plt.plot(history4.history['loss'])
plt.plot(history4.history['val_loss'])
plt.title('VGG 19 Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Training', 'Validation'])
plt.savefig('vgg19_loss.png', dpi=300) # Save plot as PNG
plt.show()

# %%
# Plot the training and validation auc
plt.plot(history4.history['auc'])
plt.plot(history4.history['val_auc'])
plt.title('VGG 19 Model AUC')
plt.xlabel('Epoch')
plt.ylabel('AUC')
plt.legend(['Training', 'Validation'])
plt.savefig('vgg19_auc.png', dpi=300) # Save plot as PNG
plt.show()

# Plot the training and validation precision
plt.plot(history4.history['precision'])
plt.plot(history4.history['val_precision'])
plt.title('VGG 19 Model Precision')
plt.xlabel('Epoch')
plt.ylabel('Precision')
plt.legend(['Training', 'Validation'])
plt.savefig('vgg19_precision.png', dpi=300) # Save plot as PNG
plt.show()

# %%
import pandas as pd

# Assuming 'history1' is the History object returned from model.fit()
metrics = pd.DataFrame(history4.history)

# Save the training history to a CSV file
metrics.to_csv('/content/sample_data/VGG.csv', index=False)

# Save the model itself
model4.save('/content/sample_data/VGG.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
import tensorflow as tf
from tensorflow.keras.applications.xception import Xception

# Specify the input image size
image_size = 224
 # You can adjust this to match your dataset's image size

# Load the Xception model with pre-trained weights (include_top=False excludes the fully connected layers)
xception = Xception(weights='imagenet', include_top=False, input_shape=(image_size, image_size, 3))

# Display a summary of the Xception model
#xception.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 [==============================] - 5s 0us/step

# %%
model5 = xception.output
model5 = tf.keras.layers.AveragePooling2D(pool_size=(4, 4))(model5)
model5 = tf.keras.layers.Flatten(name="flatten")(model5)
model5 = tf.keras.layers.Dense(128, activation="relu")(model5)
model5 = tf.keras.layers.Dropout(0.6)(model5)
model5 = tf.keras.layers.Dense(4, activation='softmax')(model5)
model5 = tf.keras.models.Model(inputs=xception.input, outputs=model5)

# %%
model5.compile( optimizer='adam',
    loss='categorical_crossentropy',
    metrics=METRICS)

# %%
history5=model5.load_weights('/content/drive/MyDrive/XCEPTION.h5')

# %%
history5=model5.fit(xtrain,ytrain,epochs=50,validation_data=(xtest,ytest))
# Out:
# Epoch 1/50
# 530/530 [==============================] - 317s 522ms/step - loss: 0.3790 - accuracy: 0.9375 - precision: 0.8996 - recall: 0.8444 - auc: 0.9743 - val_loss: 0.3641 - val_accuracy: 0.9459 - val_precision: 0.9000 - val_recall: 0.8814 - val_auc: 0.9778
# Epoch 2/50
# 530/530 [==============================] - 285s 539ms/step - loss: 0.2180 - accuracy: 0.9641 - precision: 0.9340 - recall: 0.9217 - auc: 0.9898 - val_loss: 0.7391 - val_accuracy: 0.8918 - val_precision: 0.7907 - val_recall: 0.7715 - val_auc: 0.9359
# Epoch 3/50
# 530/530 [==============================] - 285s 538ms/step - loss: 0.1797 - accuracy: 0.9707 - precision: 0.9446 - recall: 0.9376 - auc: 0.9928 - val_loss: 0.5332 - val_accuracy: 0.9328 - val_precision: 0.8673 - val_recall: 0.8632 - val_auc: 0.9655
# Epoch 4/50
# 530/530 [==============================] - 286s 539ms/step - loss: 0.1397 - accuracy: 0.9772 - precision: 0.9566 - recall: 0.9520 - auc: 0.9952 - val_loss: 0.1670 - val_accuracy: 0.9706 - val_precision: 0.9423 - val_recall: 0.9399 - val_auc: 0.9932
# Epoch 5/50
# 530/530 [==============================] - 285s 539ms/step - loss: 0.1281 - accuracy: 0.9788 - precision: 0.9594 - recall: 0.9558 - auc: 0.9957 - val_loss: 0.3614 - val_accuracy: 0.9333 - val_precision: 0.8700 - val_recall: 0.8618 - val_auc: 0.9779
# Epoch 6/50
# 530/530 [==============================] - 286s 539ms/step - loss: 0.0974 - accuracy: 0.9847 - precision: 0.9705 - recall: 0.9683 - auc: 0.9970 - val_loss: 0.4856 - val_accuracy: 0.9463 - val_precision: 0.8940 - val_recall: 0.8908 - val_auc: 0.9703
# Epoch 7/50
# 530/530 [==============================] - 285s 538ms/step - loss: 0.0737 - accuracy: 0.9879 - precision: 0.9766 - recall: 0.9751 - auc: 0.9982 - val_loss: 0.2609 - val_accuracy: 0.9686 - val_precision: 0.9389 - val_recall: 0.9354 - val_auc: 0.9868
# Epoch 8/50
# 530/530 [==============================] - 285s 538ms/step - loss: 0.0828 - accuracy: 0.9871 - precision: 0.9760 - recall: 0.9725 - auc: 0.9978 - val_loss: 1.1180 - val_accuracy: 0.9267 - val_precision: 0.8546 - val_recall: 0.8514 - val_auc: 0.9429
# Epoch 9/50
# 530/530 [==============================] - 285s 538ms/step - loss: 0.0674 - accuracy: 0.9893 - precision: 0.9792 - recall: 0.9778 - auc: 0.9983 - val_loss: 1.9624 - val_accuracy: 0.8833 - val_precision: 0.7681 - val_recall: 0.7639 - val_auc: 0.8971
# Epoch 10/50
# 530/530 [==============================] - 285s 538ms/step - loss: 0.0729 - accuracy: 0.9881 - precision: 0.9776 - recall: 0.9747 - auc: 0.9982 - val_loss: 3.5009 - val_accuracy: 0.7279 - val_precision: 0.4555 - val_recall: 0.4528 - val_auc: 0.7203
# Epoch 11/50
# 530/530 [==============================] - 285s 538ms/step - loss: 0.0440 - accuracy: 0.9930 - precision: 0.9863 - recall: 0.9856 - auc: 0.9990 - val_loss: 0.6533 - val_accuracy: 0.9435 - val_precision: 0.8879 - val_recall: 0.8858 - val_auc: 0.9644
# Epoch 12/50
# 530/530 [==============================] - 285s 538ms/step - loss: 0.0465 - accuracy: 0.9927 - precision: 0.9861 - recall: 0.9847 - auc: 0.9989 - val_loss: 0.3084 - val_accuracy: 0.9667 - val_precision: 0.9345 - val_recall: 0.9323 - val_auc: 0.9827
# Epoch 13/50
# 530/530 [==============================] - 285s 538ms/step - loss: 0.0327 - accuracy: 0.9946 - precision: 0.9895 - recall: 0.9887 - auc: 0.9994 - val_loss: 0.4550 - val_accuracy: 0.9659 - val_precision: 0.9320 - val_recall: 0.9314 - val_auc: 0.9769
# Epoch 14/50
# 530/530 [==============================] - 285s 538ms/step - loss: 0.0416 - accuracy: 0.9935 - precision: 0.9874 - recall: 0.9867 - auc: 0.9991 - val_loss: 0.9270 - val_accuracy: 0.9422 - val_precision: 0.8852 - val_recall: 0.8835 - val_auc: 0.9531
# Epoch 15/50
# 530/530 [==============================] - 285s 538ms/step - loss: 0.0368 - accuracy: 0.9946 - precision: 0.9897 - recall: 0.9888 - auc: 0.9991 - val_loss: 0.5450 - val_accuracy: 0.9692 - val_precision: 0.9391 - val_recall: 0.9377 - val_auc: 0.9745
# Epoch 16/50
# 530/530 [==============================] - 285s 538ms/step - loss: 0.0323 - accuracy: 0.9951 - precision: 0.9904 - recall: 0.9899 - auc: 0.9994 - val_loss: 0.4045 - val_accuracy: 0.9686 - val_precision: 0.9375 - val_recall: 0.9368 - val_auc: 0.9823
# Epoch 17/50
# 530/530 [==============================] - 285s 538ms/step - loss: 0.0277 - accuracy: 0.9960 - precision: 0.9924 - recall: 0.9914 - auc: 0.9994 - val_loss: 0.3708 - val_accuracy: 0.9688 - val_precision: 0.9379 - val_recall: 0.9373 - val_auc: 0.9817
# Epoch 18/50
# 530/530 [==============================] - 285s 538ms/step - loss: 0.0298 - accuracy: 0.9957 - precision: 0.9917 - recall: 0.9910 - auc: 0.9993 - val_loss: 0.3515 - val_accuracy: 0.9602 - val_precision: 0.9219 - val_recall: 0.9186 - val_auc: 0.9811
# Epoch 19/50
# 530/530 [==============================] - 285s 538ms/step - loss: 0.0324 - accuracy: 0.9952 - precision: 0.9910 - recall: 0.9899 - auc: 0.9993 - val_loss: 0.5331 - val_accuracy: 0.9442 - val_precision: 0.8901 - val_recall: 0.8863 - val_auc: 0.9682
# Epoch 20/50
# 530/530 [==============================] - 285s 538ms/step - loss: 0.0271 - accuracy: 0.9960 - precision: 0.9922 - recall: 0.9919 - auc: 0.9994 - val_loss: 0.4842 - val_accuracy: 0.9693 - val_precision: 0.9389 - val_recall: 0.9384 - val_auc: 0.9799
# Epoch 21/50
# 530/530 [==============================] - 285s 538ms/step - loss: 0.0258 - accuracy: 0.9963 - precision: 0.9927 - recall: 0.9924 - auc: 0.9994 - val_loss: 0.3122 - val_accuracy: 0.9650 - val_precision: 0.9304 - val_recall: 0.9295 - val_auc: 0.9834
# Epoch 22/50
# 530/530 [==============================] - 285s 538ms/step - loss: 0.0135 - accuracy: 0.9981 - precision: 0.9964 - recall: 0.9962 - auc: 0.9998 - val_loss: 0.3804 - val_accuracy: 0.9653 - val_precision: 0.9311 - val_recall: 0.9302 - val_auc: 0.9811
# Epoch 23/50
# 530/530 [==============================] - 285s 537ms/step - loss: 0.0212 - accuracy: 0.9968 - precision: 0.9937 - recall: 0.9935 - auc: 0.9994 - val_loss: 0.3540 - val_accuracy: 0.9649 - val_precision: 0.9303 - val_recall: 0.9290 - val_auc: 0.9797
# Epoch 24/50
# 530/530 [==============================] - 285s 537ms/step - loss: 0.0298 - accuracy: 0.9957 - precision: 0.9915 - recall: 0.9912 - auc: 0.9994 - val_loss: 0.7118 - val_accuracy: 0.9545 - val_precision: 0.9092 - val_recall: 0.9090 - val_auc: 0.9705
# Epoch 25/50
# 530/530 [==============================] - 285s 537ms/step - loss: 0.0240 - accuracy: 0.9964 - precision: 0.9931 - recall: 0.9925 - auc: 0.9995 - val_loss: 0.3150 - val_accuracy: 0.9727 - val_precision: 0.9455 - val_recall: 0.9453 - val_auc: 0.9856
# Epoch 26/50
# 530/530 [==============================] - 284s 537ms/step - loss: 0.0238 - accuracy: 0.9965 - precision: 0.9933 - recall: 0.9928 - auc: 0.9995 - val_loss: 0.4229 - val_accuracy: 0.9703 - val_precision: 0.9410 - val_recall: 0.9401 - val_auc: 0.9799
# Epoch 27/50
# 530/530 [==============================] - 284s 537ms/step - loss: 0.0275 - accuracy: 0.9954 - precision: 0.9912 - recall: 0.9903 - auc: 0.9994 - val_loss: 0.2599 - val_accuracy: 0.9639 - val_precision: 0.9292 - val_recall: 0.9259 - val_auc: 0.9863
# Epoch 28/50
# 530/530 [==============================] - 284s 537ms/step - loss: 0.0229 - accuracy: 0.9966 - precision: 0.9936 - recall: 0.9929 - auc: 0.9996 - val_loss: 0.3566 - val_accuracy: 0.9709 - val_precision: 0.9420 - val_recall: 0.9415 - val_auc: 0.9832
# Epoch 29/50
# 530/530 [==============================] - 285s 537ms/step - loss: 0.0186 - accuracy: 0.9971 - precision: 0.9943 - recall: 0.9940 - auc: 0.9996 - val_loss: 0.3180 - val_accuracy: 0.9744 - val_precision: 0.9488 - val_recall: 0.9486 - val_auc: 0.9851
# Epoch 30/50
# 530/530 [==============================] - 285s 537ms/step - loss: 0.0193 - accuracy: 0.9972 - precision: 0.9946 - recall: 0.9942 - auc: 0.9997 - val_loss: 0.3913 - val_accuracy: 0.9662 - val_precision: 0.9331 - val_recall: 0.9316 - val_auc: 0.9825
# Epoch 31/50
# 530/530 [==============================] - 284s 536ms/step - loss: 0.0201 - accuracy: 0.9970 - precision: 0.9943 - recall: 0.9936 - auc: 0.9995 - val_loss: 0.3406 - val_accuracy: 0.9683 - val_precision: 0.9370 - val_recall: 0.9363 - val_auc: 0.9825
# Epoch 32/50
# 530/530 [==============================] - 284s 535ms/step - loss: 0.0305 - accuracy: 0.9957 - precision: 0.9917 - recall: 0.9910 - auc: 0.9994 - val_loss: 0.4507 - val_accuracy: 0.9632 - val_precision: 0.9268 - val_recall: 0.9259 - val_auc: 0.9769
# Epoch 33/50
# 530/530 [==============================] - 284s 536ms/step - loss: 0.0145 - accuracy: 0.9979 - precision: 0.9959 - recall: 0.9956 - auc: 0.9998 - val_loss: 0.3338 - val_accuracy: 0.9626 - val_precision: 0.9258 - val_recall: 0.9243 - val_auc: 0.9813
# Epoch 34/50
# 530/530 [==============================] - 284s 536ms/step - loss: 0.0104 - accuracy: 0.9984 - precision: 0.9968 - recall: 0.9968 - auc: 0.9999 - val_loss: 0.4755 - val_accuracy: 0.9565 - val_precision: 0.9136 - val_recall: 0.9125 - val_auc: 0.9738
# Epoch 35/50
# 530/530 [==============================] - 284s 536ms/step - loss: 0.0112 - accuracy: 0.9982 - precision: 0.9965 - recall: 0.9965 - auc: 0.9998 - val_loss: 0.4309 - val_accuracy: 0.9685 - val_precision: 0.9370 - val_recall: 0.9368 - val_auc: 0.9789
# Epoch 36/50
# 530/530 [==============================] - 284s 536ms/step - loss: 0.0256 - accuracy: 0.9964 - precision: 0.9929 - recall: 0.9926 - auc: 0.9994 - val_loss: 0.3014 - val_accuracy: 0.9705 - val_precision: 0.9412 - val_recall: 0.9408 - val_auc: 0.9840
# Epoch 37/50
# 530/530 [==============================] - 285s 537ms/step - loss: 0.0160 - accuracy: 0.9980 - precision: 0.9959 - recall: 0.9959 - auc: 0.9996 - val_loss: 0.3947 - val_accuracy: 0.9615 - val_precision: 0.9237 - val_recall: 0.9222 - val_auc: 0.9796
# Epoch 38/50
# 530/530 [==============================] - 284s 536ms/step - loss: 0.0182 - accuracy: 0.9971 - precision: 0.9944 - recall: 0.9940 - auc: 0.9998 - val_loss: 0.4723 - val_accuracy: 0.9728 - val_precision: 0.9460 - val_recall: 0.9453 - val_auc: 0.9811
# Epoch 39/50
# 530/530 [==============================] - 283s 534ms/step - loss: 0.0162 - accuracy: 0.9980 - precision: 0.9960 - recall: 0.9959 - auc: 0.9996 - val_loss: 0.3751 - val_accuracy: 0.9742 - val_precision: 0.9486 - val_recall: 0.9483 - val_auc: 0.9817
# Epoch 40/50
# 530/530 [==============================] - 284s 535ms/step - loss: 0.0117 - accuracy: 0.9981 - precision: 0.9963 - recall: 0.9962 - auc: 0.9997 - val_loss: 0.4369 - val_accuracy: 0.9706 - val_precision: 0.9413 - val_recall: 0.9413 - val_auc: 0.9804
# Epoch 41/50
# 530/530 [==============================] - 284s 535ms/step - loss: 0.0163 - accuracy: 0.9978 - precision: 0.9956 - recall: 0.9954 - auc: 0.9997 - val_loss: 0.5424 - val_accuracy: 0.9697 - val_precision: 0.9396 - val_recall: 0.9392 - val_auc: 0.9792
# Epoch 42/50
# 530/530 [==============================] - 284s 535ms/step - loss: 0.0117 - accuracy: 0.9984 - precision: 0.9969 - recall: 0.9967 - auc: 0.9997 - val_loss: 0.6107 - val_accuracy: 0.9651 - val_precision: 0.9302 - val_recall: 0.9302 - val_auc: 0.9758
# Epoch 43/50
# 530/530 [==============================] - 283s 535ms/step - loss: 0.0140 - accuracy: 0.9977 - precision: 0.9955 - recall: 0.9954 - auc: 0.9997 - val_loss: 0.6543 - val_accuracy: 0.9732 - val_precision: 0.9464 - val_recall: 0.9462 - val_auc: 0.9768
# Epoch 44/50
# 530/530 [==============================] - 283s 534ms/step - loss: 0.0102 - accuracy: 0.9983 - precision: 0.9968 - recall: 0.9965 - auc: 0.9999 - val_loss: 0.4835 - val_accuracy: 0.9529 - val_precision: 0.9068 - val_recall: 0.9045 - val_auc: 0.9730
# Epoch 45/50
# 530/530 [==============================] - 283s 535ms/step - loss: 0.0302 - accuracy: 0.9962 - precision: 0.9927 - recall: 0.9921 - auc: 0.9994 - val_loss: 0.2951 - val_accuracy: 0.9701 - val_precision: 0.9403 - val_recall: 0.9401 - val_auc: 0.9848
# Epoch 46/50
# 530/530 [==============================] - 283s 535ms/step - loss: 0.0109 - accuracy: 0.9985 - precision: 0.9970 - recall: 0.9969 - auc: 0.9998 - val_loss: 0.3220 - val_accuracy: 0.9652 - val_precision: 0.9312 - val_recall: 0.9295 - val_auc: 0.9823
# Epoch 47/50
# 530/530 [==============================] - 283s 534ms/step - loss: 0.0128 - accuracy: 0.9981 - precision: 0.9965 - recall: 0.9960 - auc: 0.9998 - val_loss: 0.4480 - val_accuracy: 0.9632 - val_precision: 0.9270 - val_recall: 0.9257 - val_auc: 0.9768
# Epoch 48/50
# 530/530 [==============================] - 283s 534ms/step - loss: 0.0079 - accuracy: 0.9987 - precision: 0.9976 - recall: 0.9973 - auc: 0.9999 - val_loss: 0.3872 - val_accuracy: 0.9752 - val_precision: 0.9505 - val_recall: 0.9502 - val_auc: 0.9812
# Epoch 49/50
# 530/530 [==============================] - 283s 533ms/step - loss: 0.0160 - accuracy: 0.9978 - precision: 0.9956 - recall: 0.9955 - auc: 0.9997 - val_loss: 0.5363 - val_accuracy: 0.9585 - val_precision: 0.9176 - val_recall: 0.9165 - val_auc: 0.9710
# Epoch 50/50
# 530/530 [==============================] - 283s 533ms/step - loss: 0.0123 - accuracy: 0.9982 - precision: 0.9964 - recall: 0.9963 - auc: 0.9997 - val_loss: 0.3735 - val_accuracy: 0.9656 - val_precision: 0.9322 - val_recall: 0.9302 - val_auc: 0.9795

# %%
# Make predictions using model5
pred5 = model5.predict(xtest)
pred5 = np.argmax(pred5, axis=1)
actual_label5 = np.argmax(ytest, axis=1)
print(classification_report(actual_label5, pred5, target_names=labels))
# Out:
# 133/133 [==============================] - 24s 159ms/step
#                  precision    recall  f1-score   support
#
#           COVID       0.90      0.99      0.94       733
#          Normal       0.96      0.91      0.94      2057
#    Lung_Opacity       0.92      0.92      0.92      1152
# Viral Pneumonia       0.88      0.98      0.93       298
#
#        accuracy                           0.93      4240
#       macro avg       0.91      0.95      0.93      4240
#    weighted avg       0.93      0.93      0.93      4240

# %%
accuracy_score(actual_label5, pred5)
# Out:
# 0.9313679245283019

# %%
import pandas as pd

# Assuming 'history1' is the History object returned from model.fit()
metrics = pd.DataFrame(history5.history)

# Save the training history to a CSV file
metrics.to_csv('/content/sample_data/XCEPTION.csv', index=False)

# Save the model itself
model5.save('/content/sample_data/XCEPTION.h5')

# %%
# Plot the training and validation accuracy
plt.plot(history5.history['accuracy'])
plt.plot(history5.history['val_accuracy'])
plt.title('Xception Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Training', 'Validation'])
plt.savefig('XCEPTION_accuracy.png', dpi=300) # Save plot as PNG
plt.show()

# Plot the training and validation loss
plt.plot(history5.history['loss'])
plt.plot(history5.history['val_loss'])
plt.title('Xception Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Training', 'Validation'])
plt.savefig('XCEPTION_loss.png', dpi=300) # Save plot as PNG
plt.show()

# %%
# Plot the training and validation auc
plt.plot(history5.history['auc'])
plt.plot(history5.history['val_auc'])
plt.title('Xception Model AUC')
plt.xlabel('Epoch')
plt.ylabel('AUC')
plt.legend(['Training', 'Validation'])
plt.savefig('XCEPTION_auc.png', dpi=300) # Save plot as PNG
plt.show()

# Plot the training and validation precision
plt.plot(history5.history['precision'])
plt.plot(history5.history['val_precision'])
plt.title('Xception Model Precision')
plt.xlabel('Epoch')
plt.ylabel('Precision')
plt.legend(['Training', 'Validation'])
plt.savefig('XCEPTION_precision.png', dpi=300) # Save plot as PNG
plt.show()

# %%
Cm=confusion_matrix(actual_label5,pred5)
ax=plt.axes()
sns.heatmap(Cm, cmap='Blues' ,annot=True,fmt='d',
           annot_kws={'size':10},
           xticklabels=labels,
           yticklabels=labels,
           ax=ax
           )

plt.title("Confusion Matrix for Covid-19 Classification using Xception")
plt.savefig('XCEPTION_confusion.png', dpi=300) # Save plot as PNG
plt.show()

# %%
from tensorflow.keras.applications.resnet50 import ResNet50

# %%
rn = ResNet50(input_shape=(150,150,3), weights='imagenet', include_top=False)

# %%
for layer in rn.layers:
    layer.trainable = False
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Flatten,Dense
model4 = Sequential()
model4.add(rn)
model4.add(Flatten())
model4.add(Dense(4,activation="softmax"))

# %%
model4 = rn.output
model4 = tf.keras.layers.AveragePooling2D(pool_size=(4, 4))(model4)
model4 = tf.keras.layers.Flatten(name="flatten")(model4)
model4 = tf.keras.layers.Dense(128, activation="relu")(model4)
model4 = tf.keras.layers.Dropout(0.6)(model4)
model4 = tf.keras.layers.Dense(4, activation='softmax')(model4)
model4 = tf.keras.models.Model(inputs=rn.input, outputs=model4)

# %%
model4.compile( optimizer='adam',
    loss='categorical_crossentropy',
    metrics=METRICS)

# %%
history4=model4.fit(xtrain,ytrain,epochs=20,validation_data=(xtest,ytest))
# Out:
# Epoch 1/20
# 530/530 [==============================] - 38s 66ms/step - loss: 0.4890 - accuracy: 0.9592 - precision: 0.9226 - recall: 0.9133 - auc: 0.9844 - val_loss: 0.7885 - val_accuracy: 0.9439 - val_precision: 0.8901 - val_recall: 0.8847 - val_auc: 0.9643
# Epoch 2/20
# 530/530 [==============================] - 34s 63ms/step - loss: 0.4161 - accuracy: 0.9632 - precision: 0.9285 - recall: 0.9241 - auc: 0.9820 - val_loss: 0.9091 - val_accuracy: 0.9305 - val_precision: 0.8626 - val_recall: 0.8590 - val_auc: 0.9516
# Epoch 3/20
# 530/530 [==============================] - 33s 63ms/step - loss: 0.2979 - accuracy: 0.9686 - precision: 0.9386 - recall: 0.9354 - auc: 0.9870 - val_loss: 0.9221 - val_accuracy: 0.9248 - val_precision: 0.8504 - val_recall: 0.8483 - val_auc: 0.9488
# Epoch 4/20
# 530/530 [==============================] - 33s 63ms/step - loss: 0.2491 - accuracy: 0.9723 - precision: 0.9455 - recall: 0.9436 - auc: 0.9892 - val_loss: 0.7955 - val_accuracy: 0.9346 - val_precision: 0.8702 - val_recall: 0.8677 - val_auc: 0.9576
# Epoch 5/20
# 530/530 [==============================] - 33s 63ms/step - loss: 0.2759 - accuracy: 0.9750 - precision: 0.9510 - recall: 0.9486 - auc: 0.9885 - val_loss: 0.7784 - val_accuracy: 0.9384 - val_precision: 0.8781 - val_recall: 0.8750 - val_auc: 0.9605
# Epoch 6/20
# 530/530 [==============================] - 33s 63ms/step - loss: 0.2152 - accuracy: 0.9775 - precision: 0.9557 - recall: 0.9541 - auc: 0.9909 - val_loss: 0.8689 - val_accuracy: 0.9440 - val_precision: 0.8891 - val_recall: 0.8868 - val_auc: 0.9600
# Epoch 7/20
# 530/530 [==============================] - 33s 63ms/step - loss: 0.1937 - accuracy: 0.9786 - precision: 0.9579 - recall: 0.9564 - auc: 0.9918 - val_loss: 0.8544 - val_accuracy: 0.9320 - val_precision: 0.8645 - val_recall: 0.8634 - val_auc: 0.9534
# Epoch 8/20
# 530/530 [==============================] - 33s 63ms/step - loss: 0.2274 - accuracy: 0.9793 - precision: 0.9591 - recall: 0.9580 - auc: 0.9908 - val_loss: 2.0957 - val_accuracy: 0.9342 - val_precision: 0.8693 - val_recall: 0.8672 - val_auc: 0.9422
# Epoch 9/20
# 530/530 [==============================] - 33s 63ms/step - loss: 0.2315 - accuracy: 0.9798 - precision: 0.9603 - recall: 0.9587 - auc: 0.9906 - val_loss: 0.8622 - val_accuracy: 0.9404 - val_precision: 0.8812 - val_recall: 0.8802 - val_auc: 0.9588
# Epoch 10/20
# 530/530 [==============================] - 33s 63ms/step - loss: 0.1724 - accuracy: 0.9826 - precision: 0.9658 - recall: 0.9648 - auc: 0.9929 - val_loss: 0.8814 - val_accuracy: 0.9425 - val_precision: 0.8858 - val_recall: 0.8840 - val_auc: 0.9592
# Epoch 11/20
# 530/530 [==============================] - 33s 63ms/step - loss: 0.1812 - accuracy: 0.9844 - precision: 0.9691 - recall: 0.9683 - auc: 0.9928 - val_loss: 0.9058 - val_accuracy: 0.9441 - val_precision: 0.8888 - val_recall: 0.8875 - val_auc: 0.9599
# Epoch 12/20
# 530/530 [==============================] - 33s 63ms/step - loss: 0.2516 - accuracy: 0.9829 - precision: 0.9660 - recall: 0.9654 - auc: 0.9911 - val_loss: 1.0624 - val_accuracy: 0.9438 - val_precision: 0.8882 - val_recall: 0.8866 - val_auc: 0.9579
# Epoch 13/20
# 530/530 [==============================] - 33s 63ms/step - loss: 0.1552 - accuracy: 0.9851 - precision: 0.9704 - recall: 0.9697 - auc: 0.9938 - val_loss: 0.9919 - val_accuracy: 0.9379 - val_precision: 0.8763 - val_recall: 0.8752 - val_auc: 0.9539
# Epoch 14/20
# 530/530 [==============================] - 33s 63ms/step - loss: 0.1428 - accuracy: 0.9857 - precision: 0.9717 - recall: 0.9709 - auc: 0.9949 - val_loss: 1.0026 - val_accuracy: 0.9395 - val_precision: 0.8803 - val_recall: 0.8774 - val_auc: 0.9553
# Epoch 15/20
# 530/530 [==============================] - 33s 63ms/step - loss: 0.1633 - accuracy: 0.9844 - precision: 0.9690 - recall: 0.9686 - auc: 0.9938 - val_loss: 1.2335 - val_accuracy: 0.9417 - val_precision: 0.8839 - val_recall: 0.8830 - val_auc: 0.9519
# Epoch 16/20
# 530/530 [==============================] - 34s 63ms/step - loss: 0.1356 - accuracy: 0.9875 - precision: 0.9753 - recall: 0.9748 - auc: 0.9950 - val_loss: 1.0752 - val_accuracy: 0.9455 - val_precision: 0.8914 - val_recall: 0.8903 - val_auc: 0.9571
# Epoch 17/20
# 530/530 [==============================] - 34s 64ms/step - loss: 0.1917 - accuracy: 0.9864 - precision: 0.9730 - recall: 0.9728 - auc: 0.9934 - val_loss: 1.1935 - val_accuracy: 0.9429 - val_precision: 0.8860 - val_recall: 0.8856 - val_auc: 0.9539
# Epoch 18/20
# 530/530 [==============================] - 33s 63ms/step - loss: 0.0968 - accuracy: 0.9890 - precision: 0.9780 - recall: 0.9778 - auc: 0.9963 - val_loss: 1.2264 - val_accuracy: 0.9415 - val_precision: 0.8834 - val_recall: 0.8825 - val_auc: 0.9540
# Epoch 19/20
# 530/530 [==============================] - 33s 63ms/step - loss: 0.2286 - accuracy: 0.9851 - precision: 0.9704 - recall: 0.9699 - auc: 0.9922 - val_loss: 1.2445 - val_accuracy: 0.9437 - val_precision: 0.8875 - val_recall: 0.8873 - val_auc: 0.9527
# Epoch 20/20
# 530/530 [==============================] - 33s 63ms/step - loss: 0.1079 - accuracy: 0.9892 - precision: 0.9786 - recall: 0.9782 - auc: 0.9959 - val_loss: 1.1999 - val_accuracy: 0.9405 - val_precision: 0.8815 - val_recall: 0.8804 - val_auc: 0.9495

# %%
pred4 = model4.predict(xtest)
pred4 = np.argmax(pred4, axis=1)
actual_label4 = np.argmax(ytest, axis=1)
print(classification_report(actual_label4, pred4, target_names = labels))
# Out:
# 133/133 [==============================] - 6s 48ms/step
#                  precision    recall  f1-score   support
#
#           COVID       0.92      0.85      0.89       733
#    Lung_Opacity       0.81      0.87      0.84      1217
#          Normal       0.90      0.89      0.90      1992
# Viral Pneumonia       0.95      0.92      0.93       298
#
#        accuracy                           0.88      4240
#       macro avg       0.90      0.88      0.89      4240
#    weighted avg       0.88      0.88      0.88      4240

# %%
accuracy_score(actual_label4, pred4)
# Out:
# 0.8808962264150944

# %%
import pandas as pd

# Assuming 'history1' is the History object returned from model.fit()
metrics = pd.DataFrame(history4.history)

# Save the training history to a CSV file
metrics.to_csv('/content/sample_data/RES.csv', index=False)

# Save the model itself
model4.save('/content/sample_data/RES.h5')

# %% [markdown]
# ## Comparison and Graphs of Different Model Types

# %%
# Plot the training and validation accuracy
plt.plot(history4.history['accuracy'])
plt.plot(history4.history['val_accuracy'])
plt.title('ResNet50 Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Training', 'Validation'])
plt.savefig('Resnet50_accuracy.png', dpi=300) # Save plot as PNG
plt.show()

# Plot the training and validation loss
plt.plot(history4.history['loss'])
plt.plot(history4.history['val_loss'])
plt.title('Resnet50 Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Training', 'Validation'])
plt.savefig('resnet_loss.png', dpi=300) # Save plot as PNG
plt.show()

# %%
# Plot the training and validation auc
plt.plot(history4.history['auc'])
plt.plot(history4.history['val_auc'])
plt.title('ResNet50 Model AUC')
plt.xlabel('Epoch')
plt.ylabel('AUC')
plt.legend(['Training', 'Validation'])
plt.savefig('vgg19_auc.png', dpi=300) # Save plot as PNG
plt.show()

# Plot the training and validation precision
plt.plot(history4.history['precision'])
plt.plot(history4.history['val_precision'])
plt.title('Resnet50 Model Precision')
plt.xlabel('Epoch')
plt.ylabel('Precision')
plt.legend(['Training', 'Validation'])
plt.savefig('vgg19_precision.png', dpi=300) # Save plot as PNG
plt.show()

# %%
scores  = model.evaluate(xtest, ytest, verbose=1)
scores3 = model3.evaluate(xtest, ytest, verbose=1)
#scores4 = model4.evaluate(xtest, ytest, verbose=1)
scores5 = model5.evaluate(xtest, ytest, verbose=1)
# Out:
# 133/133 [==============================] - 14s 88ms/step - loss: 0.3792 - accuracy: 0.9692 - precision: 0.9386 - recall: 0.9380 - auc: 0.9825
# 133/133 [==============================] - 10s 67ms/step - loss: 0.5532 - accuracy: 0.9693 - precision: 0.9390 - recall: 0.9383 - auc: 0.9800
# 133/133 [==============================] - 21s 151ms/step - loss: 0.3735 - accuracy: 0.9681 - precision: 0.9367 - recall: 0.9356 - auc: 0.9799

# %% [markdown]
# ## Densenet

# %%
precision = scores[0]
f1_score = scores[1]
recall = scores[2]
accuracy = scores[3]

# %% [markdown]
# ## CNN

# %%
precision3 = scores3[0]
f1_score3 = scores3[1]
recall3 = scores3[2]
accuracy3 = scores3[3]

# %% [markdown]
# ## Efficient Net B7

# %%
precision4 = scores4[0]
f1_score4 = scores4[1]
recall4 = scores4[2]
accuracy4 = scores4[3]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-81-3e68a4c055c2> in <cell line: 1>()
# ----> 1 precision4 = scores4[0]
#       2 f1_score4 = scores4[1]
#       3 recall4 = scores4[2]
#       4 accuracy4 = scores4[3]
#
# NameError: name 'scores4' is not defined

# %% [markdown]
# ## VGG 19

# %%
precision5 = scores5[0]
f1_score5 = scores5[1]
recall5 = scores5[2]
accuracy5 = scores5[3]

# %%
import pandas as pd

eval_df = pd.DataFrame(columns=['Model','Precision', 'F1 Score', 'Recall', 'Accuracy'])

# %%
eval_df = eval_df.append({'Model' : 'DenseNet-121', 'Precision': precision, 'F1 Score': f1_score, 'Recall': recall, 'Accuracy': accuracy}, ignore_index=True)
eval_df = eval_df.append({'Model' : 'Inception V3', 'Precision': precision3, 'F1 Score': f1_score3, 'Recall': recall3, 'Accuracy': accuracy3}, ignore_index=True)
#eval_df = eval_df.append({'Model' : 'VGG-19', 'Precision': precision4, 'F1 Score': f1_score4, 'Recall': recall4, 'Accuracy': accuracy4}, ignore_index=True)
eval_df = eval_df.append({'Model' : 'Xception', 'Precision': precision5, 'F1 Score': f1_score5, 'Recall': recall5, 'Accuracy': accuracy5}, ignore_index=True)

# %%
eval_df
# Out:
#           Model  Precision  F1 Score    Recall  Accuracy
# 0  DenseNet-121   0.379152  0.969163  0.938636  0.937972
# 1  Inception V3   0.553180  0.969340  0.938990  0.938325
# 2      Xception   0.373460  0.968101  0.936718  0.935613

# %%
import csv
eval_df.to_csv('comparison_metrics.csv', index=False)

# %% [markdown]
# ## Ensemble Learning

# %%
pred = model.predict(xtest)
pred1=model3.predict(xtest)
#pred2 = model4.predict(xtest)
pred3=model5.predict(xtest)
ensemble_preds = np.average([pred,pred1,pred3], axis=0)
final_preds = np.argmax(ensemble_preds, axis=1)
actual_label_final = np.argmax(ytest, axis=1)
print(classification_report(actual_label_final, final_preds,target_names = labels))
# Out:
# 133/133 [==============================] - 11s 86ms/step
# 133/133 [==============================] - 9s 64ms/step
# 133/133 [==============================] - 20s 150ms/step
#                  precision    recall  f1-score   support
#
#           COVID       0.98      0.98      0.98       733
#          Normal       0.94      0.98      0.96      2057
#    Lung_Opacity       0.96      0.89      0.93      1152
# Viral Pneumonia       0.98      0.97      0.97       298
#
#        accuracy                           0.95      4240
#       macro avg       0.96      0.96      0.96      4240
#    weighted avg       0.95      0.95      0.95      4240

# %%
accuracy_score(actual_label_final, final_preds)
# Out:
# 0.9542452830188679

# %%
history5=

# %%
Cm4=confusion_matrix(actual_label_final,final_preds)
ax3=plt.axes()
sns.heatmap(Cm4, cmap='Blues' ,annot=True,fmt='d',
           annot_kws={'size':10},
           xticklabels=labels,
           yticklabels=labels
           )

plt.title("Confusion Matrix for Covid-19 classification using Ensemble Model")
plt.savefig('ensemble_confusion.png', dpi=300) # Save plot as PNG
plt.show()

# %%
ensemble_preds.fit(xtrain,ytrain,epochs=50,validation_data=(xtest,ytest))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-72-daf32f6a9307> in <cell line: 1>()
# ----> 1 ensemble_preds.fit(xtrain,ytrain,epochs=50,validation_data=(xtest,ytest))
#
# AttributeError: 'numpy.ndarray' object has no attribute 'fit'

# %%
import pickle
with open('/kaggle/input/model-training/Model Training/ensemble_history.pkl', 'rb') as f:
    final = pickle.load(f)

# %%
# Plot the training and validation accuracy
plt.plot(final['accuracy'])
plt.plot(final['val_accuracy'])
plt.title('Ensemble Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Training', 'Validation'])
plt.savefig('ensemble_accuracy2.png', dpi=300) # Save plot as PNG
plt.show()

# Plot the training and validation loss
plt.plot(final['loss'])
plt.plot(final['val_loss'])
plt.title('Ensemble Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Training', 'Validation'])
plt.savefig('ensemble_loss2.png', dpi=300) # Save plot as PNG
plt.show()

# %%
# Plot the training and validation auc
plt.plot(final['auc'])
plt.plot(final['val_auc'])
plt.title('Ensemble Model AUC')
plt.xlabel('Epoch')
plt.ylabel('AUC')
plt.legend(['Training', 'Validation'])
plt.savefig('ensemble_auc2.png', dpi=300) # Save plot as PNG
plt.show()

# Plot the training and validation precision
plt.plot(final['precision'])
plt.plot(final['val_precision'])
plt.title('Ensemble Model Precision')
plt.xlabel('Epoch')
plt.ylabel('Precision')
plt.legend(['Training', 'Validation'])
plt.savefig('ensemble_precision2.png', dpi=300) # Save plot as PNG
plt.show()

# %% [markdown]
# ## Mean Square Error

# %%
from sklearn.metrics import mean_squared_error

pred_final1 = (pred + pred1 + pred2 + pred3)/4.0

# printing the mean squared error between real value and predicted value
print(mean_squared_error(ytest, pred_final1))
# Out:
# 0.014353122

# %% [markdown]
# ## Prediction

# %%
def imagePrediction(upload):
    for name, fileinfo  in uploader.value.items():
        image = Image.open(io.BytesIO(fileinfo['content']))

    images = cv2.cvtColor(np.array(image), cv2.COLOR_RGB2BGR)
    images = cv2.resize(images,(150, 150))
    images = images.reshape(1, 150, 150, 3)
    prd = model2.predict(images)
    prd = np.argmax(prd, axis = 1)[0]


    if prd == 0:
        prd = "Final AD JPEG"
    elif prd == 1:
        prd = "Final CN JPEG"
    elif prd == 2:
        prd = "Final EMCI JPEG"
    elif prd == 3:
        prd = "Final LMCI JPEG"
    elif prd == 4:
        prd = "Final MCI JPEG"
    if prd!=1:
        print(f'Model Predict That is  a {prd}')

# %%
uploader = widgets.FileUpload()
display(uploader)
# Out:
# FileUpload(value={}, description='Upload')

# %%
button = widgets.Button(description= "Predict")
out = widgets.Output()

def on_button_click(_):
    with out:
        clear_output()
        try:
            imagePrediction(uploader)
        except:
            print("Please Enter the Correct Image files")


button.on_click(on_button_click)
widgets.VBox([button, out])
# Out:
# VBox(children=(Button(description='Predict', style=ButtonStyle()), Output()))
